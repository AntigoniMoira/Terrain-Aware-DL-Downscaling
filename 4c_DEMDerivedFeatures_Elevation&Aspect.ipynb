# %%
# Importing the drive module from google.colab library
from google.colab import drive

# Mounting the Google Drive to the Colab environment
drive.mount('/content/drive')

project_path = '/content/drive/My Drive/DEM_Aware_Downscaling/'

import os
os.chdir(project_path)
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import time
from utils.helpers_functions import read_dataset, z_score_normalize, denormalize_mae, mean_with_land_mask, compute_slope, compute_aspect
from utils.models_functions import psnr, ssim, save_history, save_model, train_model, load_model
from utils.display_functions import plot_history, plot_to_compare, plot_per_pixel_metrics, plot_degrees_mae
from utils.evaluation_functions import evaluate_per_pixel

# %%
dem_path='/content/drive/My Drive/DEM_Aware_Downscaling/dem_data/'
dates_path='/content/drive/My Drive/MSc_Thesis/input_data/index/'
lr_data_path='/content/drive/My Drive/MSc_Thesis/input_data/deg/0_5x0_5/'
hr_data_path='/content/drive/My Drive/MSc_Thesis/input_data/deg/0_25x0_25/'
global_mean = 286.307980744908
global_Std = 64.2568020375484
target_size = (320, 580)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, Add, LeakyReLU, Lambda, Conv2DTranspose, Concatenate
from tensorflow.keras.models import Model

# Load DEMs
dem_data_0_5 = np.load(dem_path + "dem_0_5.npy")
dem_data_0_25 = np.load(dem_path + "dem_0_25.npy")

# Compute aspect
aspect_0_5 = compute_aspect(dem_data_0_5)
aspect_0_25 = compute_aspect(dem_data_0_25)

# Normalize static features
dem_data_0_5 = z_score_normalize(dem_data_0_5, np.mean(dem_data_0_5), np.std(dem_data_0_5))
aspect_0_5 = z_score_normalize(aspect_0_5, np.mean(aspect_0_5), np.std(aspect_0_5))

dem_data_0_25 = z_score_normalize(dem_data_0_25, np.mean(dem_data_0_25), np.std(dem_data_0_25))
aspect_0_25 = z_score_normalize(aspect_0_25, np.mean(aspect_0_25), np.std(aspect_0_25))

# ---- Convert to Tensors and Expand ----
def to_tensor(x): return tf.expand_dims(tf.constant(x, dtype=tf.float32), axis=-1)

dem_tensor_0_5 = to_tensor(dem_data_0_5)
aspect_tensor_0_5 = to_tensor(aspect_0_5)

dem_tensor_0_25 = to_tensor(dem_data_0_25)
aspect_tensor_0_25 = to_tensor(aspect_0_25)

def expand_static_data_dem_0_5(x):
    batch_size = tf.shape(x)[0]
    return tf.tile(tf.expand_dims(dem_tensor_0_5, 0), [batch_size, 1, 1, 1])

def expand_static_data_dem_0_25(x):
    batch_size = tf.shape(x)[0]
    return tf.tile(tf.expand_dims(dem_tensor_0_25, 0), [batch_size, 1, 1, 1])

def expand_static_aspect_0_5(x):
    batch_size = tf.shape(x)[0]
    return tf.tile(tf.expand_dims(aspect_tensor_0_5, 0), [batch_size, 1, 1, 1])

def expand_static_aspect_0_25(x):
    batch_size = tf.shape(x)[0]
    return tf.tile(tf.expand_dims(aspect_tensor_0_25, 0), [batch_size, 1, 1, 1])

# ---- Residual Block ----
def residual_block(x, filters=32, kernel_size=3, scaling=0.1):
    res = Conv2D(filters, kernel_size, padding='same')(x)
    res = LeakyReLU(alpha=0.2)(res)
    res = Conv2D(filters, kernel_size, padding='same')(res)
    res = Lambda(lambda t: t * scaling)(res)
    return Add()([x, res])

# ---- Model ----
def create_edsr():
    input_img = Input(shape=(160, 290, 1))  # Low-resolution input

    # --- Low-Res Static Features (0.5°) ---
    static_low = Concatenate()([
         Lambda(expand_static_data_dem_0_5, output_shape=(160, 290, 1))(input_img),
         Lambda(expand_static_aspect_0_5, output_shape=(160, 290, 1))(input_img)
    ])
    x = Concatenate()([input_img, static_low])

    # Initial Conv Layer
    initial_conv = Conv2D(filters=32, kernel_size=3, padding='same')(x)

    # Residual Blocks
    x = residual_block(initial_conv, filters=32)
    x = residual_block(x, filters=32)
    x = residual_block(x, filters=32)
    x = residual_block(x, filters=32)

    x = Conv2D(filters=32, kernel_size=3, padding='same')(x)
    x = Add()([x, initial_conv])

    # Upsample (learned)
    x = Conv2DTranspose(filters=32, kernel_size=3, strides=2, padding='same')(x)

    # --- High-Res Static Features (0.25°) ---
    static_high = Concatenate()([
        Lambda(expand_static_data_dem_0_25, output_shape=(320, 580, 1))(input_img),
        Lambda(expand_static_aspect_0_25, output_shape=(320, 580, 1))(input_img)
    ])
    x = Concatenate()([x, static_high])

    # Fusion Layers
    # x = Conv2D(filters=64, kernel_size=3, padding='same', activation='relu')(x)
    x = Conv2D(filters=32, kernel_size=3, padding='same', activation='relu')(x)
    x = Conv2D(filters=16, kernel_size=3, padding='same', activation='relu')(x)
    # x = Conv2D(filters=8, kernel_size=3, padding='same', activation='relu')(x)

    # Final Conv Layer (Reduces to 1 Output Channel)
    output_img = Conv2D(filters=1, kernel_size=3, padding='same')(x)

    # Model Compilation
    model = Model(inputs=input_img, outputs=output_img)
    model.compile(optimizer='adam', loss='mae', metrics=[psnr, ssim, 'mse', 'mae'])

    return model

# %%
trainX, valX, testX, trainY, valY, testY, trainDates, valDates, testDates = read_dataset(dates_path, lr_data_path, hr_data_path, 'all', 2000, 2020, global_mean, global_Std)

print(trainX.shape)
print(trainY.shape)
print(valX.shape)
print(valY.shape)
print(testX.shape)
print(testY.shape)
# Out:
# (21478, 160, 290, 1)
# (21478, 320, 580, 1)
# (4602, 160, 290, 1)
# (4602, 320, 580, 1)
# (4604, 160, 290, 1)
# (4604, 320, 580, 1)

# %%
# Initialize the model
edsr_model = create_edsr()
edsr_model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 160, 290,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda (Lambda)     │ (None, 160, 290,  │          0 │ input_layer[0][0] │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_1 (Lambda)   │ (None, 160, 290,  │          0 │ input_layer[0][0] │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 160, 290,  │          0 │ lambda[0][0],     │
# │ (Concatenate)       │ 2)                │            │ lambda_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 160, 290,  │          0 │ input_layer[0][0… │
# │ (Concatenate)       │ 3)                │            │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 160, 290,  │        896 │ concatenate_1[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 160, 290,  │      9,248 │ conv2d[0][0]      │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu         │ (None, 160, 290,  │          0 │ conv2d_1[0][0]    │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 160, 290,  │      9,248 │ leaky_re_lu[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_2 (Lambda)   │ (None, 160, 290,  │          0 │ conv2d_2[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 160, 290,  │          0 │ conv2d[0][0],     │
# │                     │ 32)               │            │ lambda_2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 160, 290,  │      9,248 │ add[0][0]         │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_1       │ (None, 160, 290,  │          0 │ conv2d_3[0][0]    │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 160, 290,  │      9,248 │ leaky_re_lu_1[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_3 (Lambda)   │ (None, 160, 290,  │          0 │ conv2d_4[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 160, 290,  │          0 │ add[0][0],        │
# │                     │ 32)               │            │ lambda_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 160, 290,  │      9,248 │ add_1[0][0]       │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_2       │ (None, 160, 290,  │          0 │ conv2d_5[0][0]    │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 160, 290,  │      9,248 │ leaky_re_lu_2[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_4 (Lambda)   │ (None, 160, 290,  │          0 │ conv2d_6[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 160, 290,  │          0 │ add_1[0][0],      │
# │                     │ 32)               │            │ lambda_4[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 160, 290,  │      9,248 │ add_2[0][0]       │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_3       │ (None, 160, 290,  │          0 │ conv2d_7[0][0]    │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 160, 290,  │      9,248 │ leaky_re_lu_3[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_5 (Lambda)   │ (None, 160, 290,  │          0 │ conv2d_8[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 160, 290,  │          0 │ add_2[0][0],      │
# │                     │ 32)               │            │ lambda_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 160, 290,  │      9,248 │ add_3[0][0]       │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 160, 290,  │          0 │ conv2d_9[0][0],   │
# │                     │ 32)               │            │ conv2d[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_6 (Lambda)   │ (None, 320, 580,  │          0 │ input_layer[0][0] │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_7 (Lambda)   │ (None, 320, 580,  │          0 │ input_layer[0][0] │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 320, 580,  │      9,248 │ add_4[0][0]       │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 320, 580,  │          0 │ lambda_6[0][0],   │
# │ (Concatenate)       │ 2)                │            │ lambda_7[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 320, 580,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 34)               │            │ concatenate_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 320, 580,  │      9,824 │ concatenate_3[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 320, 580,  │      4,624 │ conv2d_10[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 320, 580,  │        145 │ conv2d_11[0][0]   │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 107,969 (421.75 KB)
#  Trainable params: 107,969 (421.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
start_time = time.time()
history = train_model(edsr_model, trainX, trainY, valX, valY, 250, 32, True, True, 100, 70)
end_time = time.time()

# Print the time taken
print(f"Training time: {end_time - start_time:.2f} seconds")

save_history(history.history, 'models/history_0_5to0_25_deg_dem_4c.pkl')
plot_history(history.history)

save_model(edsr_model, 'models/edsr_model_0_5to0_25_deg_dem_4c.keras')
# Out:
# Epoch 1/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 133s 150ms/step - loss: 0.0266 - mae: 0.0266 - mse: 0.0036 - psnr: 30.3239 - ssim: 0.7560 - val_loss: 0.0082 - val_mae: 0.0082 - val_mse: 1.5619e-04 - val_psnr: 38.0679 - val_ssim: 0.9641 - learning_rate: 0.0010
# Epoch 2/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0068 - mae: 0.0068 - mse: 1.2658e-04 - psnr: 39.0704 - ssim: 0.9686 - val_loss: 0.0058 - val_mae: 0.0058 - val_mse: 8.3639e-05 - val_psnr: 40.7788 - val_ssim: 0.9787 - learning_rate: 0.0010
# Epoch 3/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0054 - mae: 0.0054 - mse: 7.3860e-05 - psnr: 41.3838 - ssim: 0.9810 - val_loss: 0.0045 - val_mae: 0.0045 - val_mse: 4.8705e-05 - val_psnr: 43.1257 - val_ssim: 0.9851 - learning_rate: 0.0010
# Epoch 4/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0046 - mae: 0.0046 - mse: 4.8212e-05 - psnr: 43.2498 - ssim: 0.9855 - val_loss: 0.0053 - val_mae: 0.0053 - val_mse: 5.4947e-05 - val_psnr: 42.6055 - val_ssim: 0.9874 - learning_rate: 0.0010
# Epoch 5/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0044 - mae: 0.0044 - mse: 4.3107e-05 - psnr: 43.7184 - ssim: 0.9879 - val_loss: 0.0044 - val_mae: 0.0044 - val_mse: 4.0878e-05 - val_psnr: 43.8875 - val_ssim: 0.9891 - learning_rate: 0.0010
# Epoch 6/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0041 - mae: 0.0041 - mse: 3.8374e-05 - psnr: 44.2525 - ssim: 0.9890 - val_loss: 0.0035 - val_mae: 0.0035 - val_mse: 2.9712e-05 - val_psnr: 45.2735 - val_ssim: 0.9902 - learning_rate: 0.0010
# Epoch 7/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0039 - mae: 0.0039 - mse: 3.4974e-05 - psnr: 44.6127 - ssim: 0.9898 - val_loss: 0.0039 - val_mae: 0.0039 - val_mse: 3.4607e-05 - val_psnr: 44.6122 - val_ssim: 0.9900 - learning_rate: 0.0010
# Epoch 8/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0036 - mae: 0.0036 - mse: 2.9974e-05 - psnr: 45.2644 - ssim: 0.9904 - val_loss: 0.0032 - val_mae: 0.0032 - val_mse: 2.5024e-05 - val_psnr: 46.0194 - val_ssim: 0.9913 - learning_rate: 0.0010
# Epoch 9/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0035 - mae: 0.0035 - mse: 2.9505e-05 - psnr: 45.3690 - ssim: 0.9909 - val_loss: 0.0037 - val_mae: 0.0037 - val_mse: 3.3169e-05 - val_psnr: 44.8002 - val_ssim: 0.9909 - learning_rate: 0.0010
# Epoch 10/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0034 - mae: 0.0034 - mse: 2.7849e-05 - psnr: 45.5957 - ssim: 0.9911 - val_loss: 0.0037 - val_mae: 0.0037 - val_mse: 2.8573e-05 - val_psnr: 45.4442 - val_ssim: 0.9916 - learning_rate: 0.0010
# Epoch 11/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0034 - mae: 0.0034 - mse: 2.6842e-05 - psnr: 45.7547 - ssim: 0.9915 - val_loss: 0.0035 - val_mae: 0.0035 - val_mse: 2.8459e-05 - val_psnr: 45.4613 - val_ssim: 0.9918 - learning_rate: 0.0010
# Epoch 12/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0032 - mae: 0.0032 - mse: 2.4781e-05 - psnr: 46.1034 - ssim: 0.9918 - val_loss: 0.0027 - val_mae: 0.0027 - val_mse: 2.1577e-05 - val_psnr: 46.6628 - val_ssim: 0.9919 - learning_rate: 0.0010
# Epoch 13/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0032 - mae: 0.0032 - mse: 2.4549e-05 - psnr: 46.1449 - ssim: 0.9921 - val_loss: 0.0028 - val_mae: 0.0028 - val_mse: 2.0271e-05 - val_psnr: 46.9343 - val_ssim: 0.9918 - learning_rate: 0.0010
# Epoch 14/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0030 - mae: 0.0030 - mse: 2.2154e-05 - psnr: 46.5769 - ssim: 0.9922 - val_loss: 0.0041 - val_mae: 0.0041 - val_mse: 3.5411e-05 - val_psnr: 44.5180 - val_ssim: 0.9919 - learning_rate: 0.0010
# Epoch 15/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0031 - mae: 0.0031 - mse: 2.3695e-05 - psnr: 46.3526 - ssim: 0.9923 - val_loss: 0.0033 - val_mae: 0.0033 - val_mse: 2.4251e-05 - val_psnr: 46.1554 - val_ssim: 0.9927 - learning_rate: 0.0010
# Epoch 16/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0032 - mae: 0.0032 - mse: 2.3683e-05 - psnr: 46.3043 - ssim: 0.9927 - val_loss: 0.0029 - val_mae: 0.0029 - val_mse: 2.2256e-05 - val_psnr: 46.5300 - val_ssim: 0.9927 - learning_rate: 0.0010
# Epoch 17/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0031 - mae: 0.0031 - mse: 2.2572e-05 - psnr: 46.5023 - ssim: 0.9929 - val_loss: 0.0027 - val_mae: 0.0027 - val_mse: 1.9459e-05 - val_psnr: 47.1131 - val_ssim: 0.9930 - learning_rate: 0.0010
# Epoch 18/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0030 - mae: 0.0030 - mse: 2.1765e-05 - psnr: 46.6632 - ssim: 0.9929 - val_loss: 0.0026 - val_mae: 0.0026 - val_mse: 1.8821e-05 - val_psnr: 47.2563 - val_ssim: 0.9926 - learning_rate: 0.0010
# Epoch 19/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0029 - mae: 0.0029 - mse: 2.0306e-05 - psnr: 46.9602 - ssim: 0.9930 - val_loss: 0.0028 - val_mae: 0.0028 - val_mse: 1.9807e-05 - val_psnr: 47.0354 - val_ssim: 0.9933 - learning_rate: 0.0010
# Epoch 20/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0029 - mae: 0.0029 - mse: 2.0833e-05 - psnr: 46.8480 - ssim: 0.9932 - val_loss: 0.0026 - val_mae: 0.0026 - val_mse: 1.7144e-05 - val_psnr: 47.6623 - val_ssim: 0.9934 - learning_rate: 0.0010
# Epoch 21/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0029 - mae: 0.0029 - mse: 1.9682e-05 - psnr: 47.0860 - ssim: 0.9934 - val_loss: 0.0024 - val_mae: 0.0024 - val_mse: 1.5978e-05 - val_psnr: 47.9686 - val_ssim: 0.9936 - learning_rate: 0.0010
# Epoch 22/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0028 - mae: 0.0028 - mse: 1.9189e-05 - psnr: 47.2140 - ssim: 0.9933 - val_loss: 0.0031 - val_mae: 0.0031 - val_mse: 2.4414e-05 - val_psnr: 46.1272 - val_ssim: 0.9915 - learning_rate: 0.0010
# Epoch 23/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0026 - mae: 0.0026 - mse: 1.8413e-05 - psnr: 47.4043 - ssim: 0.9933 - val_loss: 0.0035 - val_mae: 0.0035 - val_mse: 2.5847e-05 - val_psnr: 45.8841 - val_ssim: 0.9933 - learning_rate: 0.0010
# Epoch 24/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0028 - mae: 0.0028 - mse: 1.9369e-05 - psnr: 47.2238 - ssim: 0.9934 - val_loss: 0.0025 - val_mae: 0.0025 - val_mse: 1.5701e-05 - val_psnr: 48.0443 - val_ssim: 0.9937 - learning_rate: 0.0010
# Epoch 25/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0028 - mae: 0.0028 - mse: 1.8940e-05 - psnr: 47.2651 - ssim: 0.9938 - val_loss: 0.0023 - val_mae: 0.0023 - val_mse: 1.4655e-05 - val_psnr: 48.3443 - val_ssim: 0.9939 - learning_rate: 0.0010
# Epoch 26/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0027 - mae: 0.0027 - mse: 1.7572e-05 - psnr: 47.5793 - ssim: 0.9938 - val_loss: 0.0023 - val_mae: 0.0023 - val_mse: 1.4777e-05 - val_psnr: 48.3082 - val_ssim: 0.9938 - learning_rate: 0.0010
# Epoch 27/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0027 - mae: 0.0027 - mse: 1.7880e-05 - psnr: 47.5154 - ssim: 0.9938 - val_loss: 0.0032 - val_mae: 0.0032 - val_mse: 2.1948e-05 - val_psnr: 46.5932 - val_ssim: 0.9940 - learning_rate: 0.0010
# Epoch 28/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0027 - mae: 0.0027 - mse: 1.9248e-05 - psnr: 47.2684 - ssim: 0.9936 - val_loss: 0.0026 - val_mae: 0.0026 - val_mse: 1.6873e-05 - val_psnr: 47.7313 - val_ssim: 0.9943 - learning_rate: 0.0010
# Epoch 29/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0026 - mae: 0.0026 - mse: 1.6982e-05 - psnr: 47.7211 - ssim: 0.9941 - val_loss: 0.0025 - val_mae: 0.0025 - val_mse: 1.5799e-05 - val_psnr: 48.0176 - val_ssim: 0.9940 - learning_rate: 0.0010
# Epoch 30/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0026 - mae: 0.0026 - mse: 1.6831e-05 - psnr: 47.7679 - ssim: 0.9941 - val_loss: 0.0026 - val_mae: 0.0026 - val_mse: 1.6736e-05 - val_psnr: 47.7694 - val_ssim: 0.9944 - learning_rate: 0.0010
# Epoch 31/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0026 - mae: 0.0026 - mse: 1.6213e-05 - psnr: 47.9275 - ssim: 0.9942 - val_loss: 0.0023 - val_mae: 0.0023 - val_mse: 1.5063e-05 - val_psnr: 48.2246 - val_ssim: 0.9939 - learning_rate: 0.0010
# Epoch 32/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0026 - mae: 0.0026 - mse: 1.6710e-05 - psnr: 47.7964 - ssim: 0.9942 - val_loss: 0.0026 - val_mae: 0.0026 - val_mse: 1.7225e-05 - val_psnr: 47.6424 - val_ssim: 0.9937 - learning_rate: 0.0010
# Epoch 33/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0026 - mae: 0.0026 - mse: 1.6607e-05 - psnr: 47.8334 - ssim: 0.9942 - val_loss: 0.0026 - val_mae: 0.0026 - val_mse: 1.7464e-05 - val_psnr: 47.5874 - val_ssim: 0.9945 - learning_rate: 0.0010
# Epoch 34/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0025 - mae: 0.0025 - mse: 1.5886e-05 - psnr: 48.0149 - ssim: 0.9943 - val_loss: 0.0025 - val_mae: 0.0025 - val_mse: 1.5317e-05 - val_psnr: 48.1531 - val_ssim: 0.9942 - learning_rate: 0.0010
# Epoch 35/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0024 - mae: 0.0024 - mse: 1.5288e-05 - psnr: 48.1902 - ssim: 0.9944 - val_loss: 0.0026 - val_mae: 0.0026 - val_mse: 1.7109e-05 - val_psnr: 47.6734 - val_ssim: 0.9941 - learning_rate: 0.0010
# Epoch 36/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0026 - mae: 0.0026 - mse: 1.6053e-05 - psnr: 47.9719 - ssim: 0.9944 - val_loss: 0.0023 - val_mae: 0.0023 - val_mse: 1.4974e-05 - val_psnr: 48.2551 - val_ssim: 0.9946 - learning_rate: 0.0010
# Epoch 37/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0025 - mae: 0.0025 - mse: 1.5494e-05 - psnr: 48.1251 - ssim: 0.9945 - val_loss: 0.0023 - val_mae: 0.0023 - val_mse: 1.4822e-05 - val_psnr: 48.2977 - val_ssim: 0.9946 - learning_rate: 0.0010
# Epoch 38/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0024 - mae: 0.0024 - mse: 1.4749e-05 - psnr: 48.3313 - ssim: 0.9945 - val_loss: 0.0023 - val_mae: 0.0023 - val_mse: 1.3393e-05 - val_psnr: 48.7360 - val_ssim: 0.9945 - learning_rate: 0.0010
# Epoch 39/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0024 - mae: 0.0024 - mse: 1.5121e-05 - psnr: 48.2566 - ssim: 0.9944 - val_loss: 0.0024 - val_mae: 0.0024 - val_mse: 1.3741e-05 - val_psnr: 48.6251 - val_ssim: 0.9947 - learning_rate: 0.0010
# Epoch 40/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0024 - mae: 0.0024 - mse: 1.4968e-05 - psnr: 48.2751 - ssim: 0.9946 - val_loss: 0.0038 - val_mae: 0.0038 - val_mse: 2.7053e-05 - val_psnr: 45.6830 - val_ssim: 0.9939 - learning_rate: 0.0010
# Epoch 41/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0024 - mae: 0.0024 - mse: 1.5001e-05 - psnr: 48.2840 - ssim: 0.9946 - val_loss: 0.0023 - val_mae: 0.0023 - val_mse: 1.4043e-05 - val_psnr: 48.5303 - val_ssim: 0.9949 - learning_rate: 0.0010
# Epoch 42/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0024 - mae: 0.0024 - mse: 1.4834e-05 - psnr: 48.3126 - ssim: 0.9947 - val_loss: 0.0026 - val_mae: 0.0026 - val_mse: 1.5923e-05 - val_psnr: 47.9861 - val_ssim: 0.9949 - learning_rate: 0.0010
# Epoch 43/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0024 - mae: 0.0024 - mse: 1.4144e-05 - psnr: 48.5134 - ssim: 0.9947 - val_loss: 0.0024 - val_mae: 0.0024 - val_mse: 1.4359e-05 - val_psnr: 48.4365 - val_ssim: 0.9948 - learning_rate: 0.0010
# Epoch 44/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0025 - mae: 0.0025 - mse: 1.5498e-05 - psnr: 48.2578 - ssim: 0.9945 - val_loss: 0.0022 - val_mae: 0.0022 - val_mse: 1.2854e-05 - val_psnr: 48.9151 - val_ssim: 0.9948 - learning_rate: 0.0010
# Epoch 45/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0024 - mae: 0.0024 - mse: 1.4396e-05 - psnr: 48.4543 - ssim: 0.9948 - val_loss: 0.0029 - val_mae: 0.0029 - val_mse: 1.8663e-05 - val_psnr: 47.2978 - val_ssim: 0.9947 - learning_rate: 0.0010
# Epoch 46/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0024 - mae: 0.0024 - mse: 1.4942e-05 - psnr: 48.2871 - ssim: 0.9948 - val_loss: 0.0026 - val_mae: 0.0026 - val_mse: 1.4577e-05 - val_psnr: 48.3673 - val_ssim: 0.9949 - learning_rate: 0.0010
# Epoch 47/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0024 - mae: 0.0024 - mse: 1.4259e-05 - psnr: 48.4861 - ssim: 0.9948 - val_loss: 0.0022 - val_mae: 0.0022 - val_mse: 1.2935e-05 - val_psnr: 48.8877 - val_ssim: 0.9947 - learning_rate: 0.0010
# Epoch 48/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0023 - mae: 0.0023 - mse: 1.3758e-05 - psnr: 48.6446 - ssim: 0.9948 - val_loss: 0.0022 - val_mae: 0.0022 - val_mse: 1.2833e-05 - val_psnr: 48.9218 - val_ssim: 0.9950 - learning_rate: 0.0010
# Epoch 49/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 77s 114ms/step - loss: 0.0023 - mae: 0.0023 - mse: 1.4053e-05 - psnr: 48.5591 - ssim: 0.9949 - val_loss: 0.0021 - val_mae: 0.0021 - val_mse: 1.2828e-05 - val_psnr: 48.9239 - val_ssim: 0.9949 - learning_rate: 0.0010
# Epoch 50/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0025 - mae: 0.0025 - mse: 1.5532e-05 - psnr: 48.1874 - ssim: 0.9946 - val_loss: 0.0022 - val_mae: 0.0022 - val_mse: 1.2630e-05 - val_psnr: 48.9904 - val_ssim: 0.9951 - learning_rate: 0.0010
# Epoch 51/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0022 - mae: 0.0022 - mse: 1.3416e-05 - psnr: 48.7587 - ssim: 0.9950 - val_loss: 0.0027 - val_mae: 0.0027 - val_mse: 1.5893e-05 - val_psnr: 47.9951 - val_ssim: 0.9950 - learning_rate: 0.0010
# Epoch 52/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 77s 114ms/step - loss: 0.0024 - mae: 0.0024 - mse: 1.4122e-05 - psnr: 48.5310 - ssim: 0.9950 - val_loss: 0.0024 - val_mae: 0.0024 - val_mse: 1.3575e-05 - val_psnr: 48.6800 - val_ssim: 0.9950 - learning_rate: 0.0010
# Epoch 53/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 77s 114ms/step - loss: 0.0023 - mae: 0.0023 - mse: 1.4038e-05 - psnr: 48.5576 - ssim: 0.9950 - val_loss: 0.0022 - val_mae: 0.0022 - val_mse: 1.2501e-05 - val_psnr: 49.0376 - val_ssim: 0.9952 - learning_rate: 0.0010
# Epoch 54/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0022 - mae: 0.0022 - mse: 1.3121e-05 - psnr: 48.8474 - ssim: 0.9950 - val_loss: 0.0023 - val_mae: 0.0023 - val_mse: 1.2950e-05 - val_psnr: 48.8822 - val_ssim: 0.9948 - learning_rate: 0.0010
# Epoch 55/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 77s 114ms/step - loss: 0.0022 - mae: 0.0022 - mse: 1.2877e-05 - psnr: 48.9365 - ssim: 0.9951 - val_loss: 0.0024 - val_mae: 0.0024 - val_mse: 1.4955e-05 - val_psnr: 48.2637 - val_ssim: 0.9953 - learning_rate: 0.0010
# Epoch 56/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0023 - mae: 0.0023 - mse: 1.3546e-05 - psnr: 48.7142 - ssim: 0.9951 - val_loss: 0.0030 - val_mae: 0.0030 - val_mse: 1.9430e-05 - val_psnr: 47.1270 - val_ssim: 0.9950 - learning_rate: 0.0010
# Epoch 57/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 77s 114ms/step - loss: 0.0023 - mae: 0.0023 - mse: 1.3394e-05 - psnr: 48.7751 - ssim: 0.9951 - val_loss: 0.0024 - val_mae: 0.0024 - val_mse: 1.3205e-05 - val_psnr: 48.7988 - val_ssim: 0.9950 - learning_rate: 0.0010
# Epoch 58/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 77s 114ms/step - loss: 0.0023 - mae: 0.0023 - mse: 1.3488e-05 - psnr: 48.7301 - ssim: 0.9951 - val_loss: 0.0024 - val_mae: 0.0024 - val_mse: 1.3355e-05 - val_psnr: 48.7495 - val_ssim: 0.9951 - learning_rate: 0.0010
# Epoch 59/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 77s 114ms/step - loss: 0.0023 - mae: 0.0023 - mse: 1.3292e-05 - psnr: 48.7927 - ssim: 0.9952 - val_loss: 0.0028 - val_mae: 0.0028 - val_mse: 1.7521e-05 - val_psnr: 47.5761 - val_ssim: 0.9954 - learning_rate: 0.0010
# Epoch 60/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0022 - mae: 0.0022 - mse: 1.3227e-05 - psnr: 48.8287 - ssim: 0.9951 - val_loss: 0.0022 - val_mae: 0.0022 - val_mse: 1.2325e-05 - val_psnr: 49.0986 - val_ssim: 0.9953 - learning_rate: 0.0010
# Epoch 61/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 77s 114ms/step - loss: 0.0021 - mae: 0.0021 - mse: 1.2282e-05 - psnr: 49.1355 - ssim: 0.9952 - val_loss: 0.0024 - val_mae: 0.0024 - val_mse: 1.2831e-05 - val_psnr: 48.9226 - val_ssim: 0.9950 - learning_rate: 0.0010
# Epoch 62/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 77s 114ms/step - loss: 0.0022 - mae: 0.0022 - mse: 1.2780e-05 - psnr: 48.9558 - ssim: 0.9952 - val_loss: 0.0021 - val_mae: 0.0021 - val_mse: 1.1767e-05 - val_psnr: 49.2989 - val_ssim: 0.9954 - learning_rate: 0.0010
# Epoch 63/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0022 - mae: 0.0022 - mse: 1.2539e-05 - psnr: 49.0542 - ssim: 0.9953 - val_loss: 0.0024 - val_mae: 0.0024 - val_mse: 1.3234e-05 - val_psnr: 48.7881 - val_ssim: 0.9954 - learning_rate: 0.0010
# Epoch 64/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0022 - mae: 0.0022 - mse: 1.2609e-05 - psnr: 49.0203 - ssim: 0.9953 - val_loss: 0.0022 - val_mae: 0.0022 - val_mse: 1.2444e-05 - val_psnr: 49.0587 - val_ssim: 0.9954 - learning_rate: 0.0010
# Epoch 65/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0022 - mae: 0.0022 - mse: 1.2862e-05 - psnr: 48.9302 - ssim: 0.9953 - val_loss: 0.0027 - val_mae: 0.0027 - val_mse: 1.6213e-05 - val_psnr: 47.9050 - val_ssim: 0.9949 - learning_rate: 0.0010
# Epoch 66/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0023 - mae: 0.0023 - mse: 1.3619e-05 - psnr: 48.7248 - ssim: 0.9951 - val_loss: 0.0022 - val_mae: 0.0022 - val_mse: 1.2873e-05 - val_psnr: 48.9112 - val_ssim: 0.9955 - learning_rate: 0.0010
# Epoch 67/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0022 - mae: 0.0022 - mse: 1.2536e-05 - psnr: 49.0404 - ssim: 0.9953 - val_loss: 0.0021 - val_mae: 0.0021 - val_mse: 1.1893e-05 - val_psnr: 49.2538 - val_ssim: 0.9954 - learning_rate: 0.0010
# Epoch 68/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0022 - mae: 0.0022 - mse: 1.2340e-05 - psnr: 49.1076 - ssim: 0.9953 - val_loss: 0.0021 - val_mae: 0.0021 - val_mse: 1.2330e-05 - val_psnr: 49.0992 - val_ssim: 0.9954 - learning_rate: 0.0010
# Epoch 69/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0022 - mae: 0.0022 - mse: 1.2266e-05 - psnr: 49.1391 - ssim: 0.9953 - val_loss: 0.0019 - val_mae: 0.0019 - val_mse: 1.0874e-05 - val_psnr: 49.6429 - val_ssim: 0.9955 - learning_rate: 0.0010
# Epoch 70/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0022 - mae: 0.0022 - mse: 1.2432e-05 - psnr: 49.0886 - ssim: 0.9953 - val_loss: 0.0023 - val_mae: 0.0023 - val_mse: 1.2748e-05 - val_psnr: 48.9517 - val_ssim: 0.9955 - learning_rate: 0.0010
# Epoch 71/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0022 - mae: 0.0022 - mse: 1.2079e-05 - psnr: 49.2023 - ssim: 0.9954 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.1272e-05 - val_psnr: 49.4865 - val_ssim: 0.9952 - learning_rate: 0.0010
# Epoch 72/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0022 - mae: 0.0022 - mse: 1.2552e-05 - psnr: 49.0533 - ssim: 0.9953 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.1422e-05 - val_psnr: 49.4300 - val_ssim: 0.9955 - learning_rate: 0.0010
# Epoch 73/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0022 - mae: 0.0022 - mse: 1.2120e-05 - psnr: 49.1891 - ssim: 0.9954 - val_loss: 0.0021 - val_mae: 0.0021 - val_mse: 1.1745e-05 - val_psnr: 49.3083 - val_ssim: 0.9955 - learning_rate: 0.0010
# Epoch 74/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0022 - mae: 0.0022 - mse: 1.2524e-05 - psnr: 49.0482 - ssim: 0.9954 - val_loss: 0.0019 - val_mae: 0.0019 - val_mse: 1.0758e-05 - val_psnr: 49.6899 - val_ssim: 0.9956 - learning_rate: 0.0010
# Epoch 75/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0022 - mae: 0.0022 - mse: 1.2035e-05 - psnr: 49.2215 - ssim: 0.9954 - val_loss: 0.0022 - val_mae: 0.0022 - val_mse: 1.1972e-05 - val_psnr: 49.2230 - val_ssim: 0.9956 - learning_rate: 0.0010
# Epoch 76/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0022 - mae: 0.0022 - mse: 1.2229e-05 - psnr: 49.1566 - ssim: 0.9954 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.1152e-05 - val_psnr: 49.5330 - val_ssim: 0.9955 - learning_rate: 0.0010
# Epoch 77/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0022 - mae: 0.0022 - mse: 1.2100e-05 - psnr: 49.1982 - ssim: 0.9955 - val_loss: 0.0024 - val_mae: 0.0024 - val_mse: 1.3067e-05 - val_psnr: 48.8451 - val_ssim: 0.9953 - learning_rate: 0.0010
# Epoch 78/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0022 - mae: 0.0022 - mse: 1.2230e-05 - psnr: 49.1479 - ssim: 0.9954 - val_loss: 0.0019 - val_mae: 0.0019 - val_mse: 1.0518e-05 - val_psnr: 49.7878 - val_ssim: 0.9956 - learning_rate: 0.0010
# Epoch 79/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0022 - mae: 0.0022 - mse: 1.2601e-05 - psnr: 49.0450 - ssim: 0.9954 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.1075e-05 - val_psnr: 49.5630 - val_ssim: 0.9954 - learning_rate: 0.0010
# Epoch 80/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0021 - mae: 0.0021 - mse: 1.1837e-05 - psnr: 49.2983 - ssim: 0.9955 - val_loss: 0.0023 - val_mae: 0.0023 - val_mse: 1.2875e-05 - val_psnr: 48.9090 - val_ssim: 0.9955 - learning_rate: 0.0010
# Epoch 81/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0022 - mae: 0.0022 - mse: 1.2328e-05 - psnr: 49.1435 - ssim: 0.9955 - val_loss: 0.0019 - val_mae: 0.0019 - val_mse: 1.0623e-05 - val_psnr: 49.7436 - val_ssim: 0.9957 - learning_rate: 0.0010
# Epoch 82/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.0952e-05 - psnr: 49.6206 - ssim: 0.9956 - val_loss: 0.0029 - val_mae: 0.0029 - val_mse: 1.7861e-05 - val_psnr: 47.4845 - val_ssim: 0.9946 - learning_rate: 0.0010
# Epoch 83/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0023 - mae: 0.0023 - mse: 1.2928e-05 - psnr: 48.9338 - ssim: 0.9954 - val_loss: 0.0026 - val_mae: 0.0026 - val_mse: 1.6282e-05 - val_psnr: 47.8906 - val_ssim: 0.9953 - learning_rate: 0.0010
# Epoch 84/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0022 - mae: 0.0022 - mse: 1.2287e-05 - psnr: 49.1402 - ssim: 0.9955 - val_loss: 0.0023 - val_mae: 0.0023 - val_mse: 1.3095e-05 - val_psnr: 48.8387 - val_ssim: 0.9956 - learning_rate: 0.0010
# Epoch 85/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0022 - mae: 0.0022 - mse: 1.2512e-05 - psnr: 49.0678 - ssim: 0.9955 - val_loss: 0.0023 - val_mae: 0.0023 - val_mse: 1.2229e-05 - val_psnr: 49.1326 - val_ssim: 0.9957 - learning_rate: 0.0010
# Epoch 86/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0021 - mae: 0.0021 - mse: 1.1697e-05 - psnr: 49.3449 - ssim: 0.9955 - val_loss: 0.0025 - val_mae: 0.0025 - val_mse: 1.4343e-05 - val_psnr: 48.4396 - val_ssim: 0.9955 - learning_rate: 0.0010
# Epoch 87/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0021 - mae: 0.0021 - mse: 1.2031e-05 - psnr: 49.2201 - ssim: 0.9956 - val_loss: 0.0023 - val_mae: 0.0023 - val_mse: 1.2521e-05 - val_psnr: 49.0293 - val_ssim: 0.9956 - learning_rate: 0.0010
# Epoch 88/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0021 - mae: 0.0021 - mse: 1.1717e-05 - psnr: 49.3326 - ssim: 0.9956 - val_loss: 0.0022 - val_mae: 0.0022 - val_mse: 1.1811e-05 - val_psnr: 49.2852 - val_ssim: 0.9955 - learning_rate: 0.0010
# Epoch 89/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0021 - mae: 0.0021 - mse: 1.1784e-05 - psnr: 49.3081 - ssim: 0.9956 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.0605e-05 - val_psnr: 49.7515 - val_ssim: 0.9956 - learning_rate: 0.0010
# Epoch 90/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0021 - mae: 0.0021 - mse: 1.1408e-05 - psnr: 49.4653 - ssim: 0.9956 - val_loss: 0.0019 - val_mae: 0.0019 - val_mse: 1.0394e-05 - val_psnr: 49.8395 - val_ssim: 0.9955 - learning_rate: 0.0010
# Epoch 91/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0021 - mae: 0.0021 - mse: 1.1737e-05 - psnr: 49.3305 - ssim: 0.9956 - val_loss: 0.0019 - val_mae: 0.0019 - val_mse: 1.0771e-05 - val_psnr: 49.6845 - val_ssim: 0.9955 - learning_rate: 0.0010
# Epoch 92/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0021 - mae: 0.0021 - mse: 1.1779e-05 - psnr: 49.3114 - ssim: 0.9956 - val_loss: 0.0022 - val_mae: 0.0022 - val_mse: 1.2069e-05 - val_psnr: 49.1916 - val_ssim: 0.9958 - learning_rate: 0.0010
# Epoch 93/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0021 - mae: 0.0021 - mse: 1.1459e-05 - psnr: 49.4299 - ssim: 0.9956 - val_loss: 0.0021 - val_mae: 0.0021 - val_mse: 1.1299e-05 - val_psnr: 49.4770 - val_ssim: 0.9956 - learning_rate: 0.0010
# Epoch 94/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0021 - mae: 0.0021 - mse: 1.1188e-05 - psnr: 49.5332 - ssim: 0.9956 - val_loss: 0.0022 - val_mae: 0.0022 - val_mse: 1.2008e-05 - val_psnr: 49.2119 - val_ssim: 0.9956 - learning_rate: 0.0010
# Epoch 95/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0021 - mae: 0.0021 - mse: 1.1832e-05 - psnr: 49.2932 - ssim: 0.9956 - val_loss: 0.0025 - val_mae: 0.0025 - val_mse: 1.3676e-05 - val_psnr: 48.6453 - val_ssim: 0.9957 - learning_rate: 0.0010
# Epoch 96/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.1332e-05 - psnr: 49.4865 - ssim: 0.9956 - val_loss: 0.0023 - val_mae: 0.0023 - val_mse: 1.3874e-05 - val_psnr: 48.5878 - val_ssim: 0.9955 - learning_rate: 0.0010
# Epoch 97/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.1532e-05 - psnr: 49.4091 - ssim: 0.9956 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.1178e-05 - val_psnr: 49.5239 - val_ssim: 0.9956 - learning_rate: 0.0010
# Epoch 98/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0021 - mae: 0.0021 - mse: 1.1523e-05 - psnr: 49.4089 - ssim: 0.9956 - val_loss: 0.0017 - val_mae: 0.0017 - val_mse: 9.9299e-06 - val_psnr: 50.0384 - val_ssim: 0.9957 - learning_rate: 0.0010
# Epoch 99/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.0885e-05 - psnr: 49.6542 - ssim: 0.9957 - val_loss: 0.0023 - val_mae: 0.0023 - val_mse: 1.2992e-05 - val_psnr: 48.8727 - val_ssim: 0.9956 - learning_rate: 0.0010
# Epoch 100/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0582e-05 - psnr: 49.7775 - ssim: 0.9957 - val_loss: 0.0021 - val_mae: 0.0021 - val_mse: 1.1476e-05 - val_psnr: 49.4097 - val_ssim: 0.9957 - learning_rate: 0.0010
# Epoch 101/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0021 - mae: 0.0021 - mse: 1.1539e-05 - psnr: 49.4030 - ssim: 0.9957 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.0933e-05 - val_psnr: 49.6191 - val_ssim: 0.9956 - learning_rate: 0.0010
# Epoch 102/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 77s 114ms/step - loss: 0.0021 - mae: 0.0021 - mse: 1.1563e-05 - psnr: 49.3943 - ssim: 0.9957 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.1218e-05 - val_psnr: 49.5087 - val_ssim: 0.9956 - learning_rate: 0.0010
# Epoch 103/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0021 - mae: 0.0021 - mse: 1.1226e-05 - psnr: 49.5170 - ssim: 0.9957 - val_loss: 0.0018 - val_mae: 0.0018 - val_mse: 1.0260e-05 - val_psnr: 49.8949 - val_ssim: 0.9958 - learning_rate: 0.0010
# Epoch 104/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.1148e-05 - psnr: 49.5465 - ssim: 0.9958 - val_loss: 0.0019 - val_mae: 0.0019 - val_mse: 1.0399e-05 - val_psnr: 49.8368 - val_ssim: 0.9958 - learning_rate: 0.0010
# Epoch 105/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.1021e-05 - psnr: 49.5967 - ssim: 0.9957 - val_loss: 0.0019 - val_mae: 0.0019 - val_mse: 1.0122e-05 - val_psnr: 49.9551 - val_ssim: 0.9958 - learning_rate: 0.0010
# Epoch 106/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.1082e-05 - psnr: 49.5957 - ssim: 0.9957 - val_loss: 0.0021 - val_mae: 0.0021 - val_mse: 1.1122e-05 - val_psnr: 49.5469 - val_ssim: 0.9958 - learning_rate: 0.0010
# Epoch 107/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.1076e-05 - psnr: 49.5807 - ssim: 0.9957 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.1052e-05 - val_psnr: 49.5718 - val_ssim: 0.9956 - learning_rate: 0.0010
# Epoch 108/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0021 - mae: 0.0021 - mse: 1.1274e-05 - psnr: 49.5055 - ssim: 0.9957 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.0952e-05 - val_psnr: 49.6116 - val_ssim: 0.9957 - learning_rate: 0.0010
# Epoch 109/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0021 - mae: 0.0021 - mse: 1.1391e-05 - psnr: 49.4678 - ssim: 0.9957 - val_loss: 0.0021 - val_mae: 0.0021 - val_mse: 1.1056e-05 - val_psnr: 49.5718 - val_ssim: 0.9957 - learning_rate: 0.0010
# Epoch 110/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.1003e-05 - psnr: 49.6062 - ssim: 0.9957 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.0361e-05 - val_psnr: 49.8530 - val_ssim: 0.9958 - learning_rate: 0.0010
# Epoch 111/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.0584e-05 - psnr: 49.7727 - ssim: 0.9958 - val_loss: 0.0018 - val_mae: 0.0018 - val_mse: 1.0237e-05 - val_psnr: 49.9052 - val_ssim: 0.9958 - learning_rate: 0.0010
# Epoch 112/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.0807e-05 - psnr: 49.6872 - ssim: 0.9957 - val_loss: 0.0021 - val_mae: 0.0021 - val_mse: 1.1091e-05 - val_psnr: 49.5570 - val_ssim: 0.9958 - learning_rate: 0.0010
# Epoch 113/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0021 - mae: 0.0021 - mse: 1.1296e-05 - psnr: 49.5016 - ssim: 0.9958 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.0548e-05 - val_psnr: 49.7762 - val_ssim: 0.9958 - learning_rate: 0.0010
# Epoch 114/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.0763e-05 - psnr: 49.7316 - ssim: 0.9958 - val_loss: 0.0015 - val_mae: 0.0015 - val_mse: 9.4980e-06 - val_psnr: 50.2325 - val_ssim: 0.9958 - learning_rate: 0.0010
# Epoch 115/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.1062e-05 - psnr: 49.5993 - ssim: 0.9958 - val_loss: 0.0018 - val_mae: 0.0018 - val_mse: 9.8871e-06 - val_psnr: 50.0576 - val_ssim: 0.9957 - learning_rate: 0.0010
# Epoch 116/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0239e-05 - psnr: 49.9129 - ssim: 0.9958 - val_loss: 0.0025 - val_mae: 0.0025 - val_mse: 1.4926e-05 - val_psnr: 48.2717 - val_ssim: 0.9957 - learning_rate: 0.0010
# Epoch 117/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 77s 114ms/step - loss: 0.0021 - mae: 0.0021 - mse: 1.1615e-05 - psnr: 49.3928 - ssim: 0.9957 - val_loss: 0.0018 - val_mae: 0.0018 - val_mse: 9.9941e-06 - val_psnr: 50.0102 - val_ssim: 0.9958 - learning_rate: 0.0010
# Epoch 118/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 77s 114ms/step - loss: 0.0021 - mae: 0.0021 - mse: 1.1365e-05 - psnr: 49.4650 - ssim: 0.9958 - val_loss: 0.0021 - val_mae: 0.0021 - val_mse: 1.1163e-05 - val_psnr: 49.5295 - val_ssim: 0.9956 - learning_rate: 0.0010
# Epoch 119/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 77s 114ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.0807e-05 - psnr: 49.6782 - ssim: 0.9958 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.0375e-05 - val_psnr: 49.8477 - val_ssim: 0.9958 - learning_rate: 0.0010
# Epoch 120/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 77s 114ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.0846e-05 - psnr: 49.6682 - ssim: 0.9958 - val_loss: 0.0018 - val_mae: 0.0018 - val_mse: 9.6178e-06 - val_psnr: 50.1770 - val_ssim: 0.9959 - learning_rate: 0.0010
# Epoch 121/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.1125e-05 - psnr: 49.5775 - ssim: 0.9957 - val_loss: 0.0021 - val_mae: 0.0021 - val_mse: 1.1515e-05 - val_psnr: 49.3950 - val_ssim: 0.9958 - learning_rate: 0.0010
# Epoch 122/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0021 - mae: 0.0021 - mse: 1.1309e-05 - psnr: 49.4980 - ssim: 0.9958 - val_loss: 0.0018 - val_mae: 0.0018 - val_mse: 1.0100e-05 - val_psnr: 49.9662 - val_ssim: 0.9959 - learning_rate: 0.0010
# Epoch 123/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0420e-05 - psnr: 49.8395 - ssim: 0.9958 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.1019e-05 - val_psnr: 49.5870 - val_ssim: 0.9957 - learning_rate: 0.0010
# Epoch 124/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.0893e-05 - psnr: 49.6470 - ssim: 0.9958 - val_loss: 0.0021 - val_mae: 0.0021 - val_mse: 1.1651e-05 - val_psnr: 49.3455 - val_ssim: 0.9959 - learning_rate: 0.0010
# Epoch 125/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.0782e-05 - psnr: 49.6894 - ssim: 0.9959 - val_loss: 0.0019 - val_mae: 0.0019 - val_mse: 1.0264e-05 - val_psnr: 49.8944 - val_ssim: 0.9958 - learning_rate: 0.0010
# Epoch 126/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.0730e-05 - psnr: 49.7148 - ssim: 0.9958 - val_loss: 0.0021 - val_mae: 0.0021 - val_mse: 1.0960e-05 - val_psnr: 49.6101 - val_ssim: 0.9959 - learning_rate: 0.0010
# Epoch 127/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 77s 114ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.0925e-05 - psnr: 49.6382 - ssim: 0.9958 - val_loss: 0.0025 - val_mae: 0.0025 - val_mse: 1.2888e-05 - val_psnr: 48.9036 - val_ssim: 0.9956 - learning_rate: 0.0010
# Epoch 128/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 77s 114ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0530e-05 - psnr: 49.8004 - ssim: 0.9958 - val_loss: 0.0018 - val_mae: 0.0018 - val_mse: 1.0208e-05 - val_psnr: 49.9188 - val_ssim: 0.9958 - learning_rate: 0.0010
# Epoch 129/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.0673e-05 - psnr: 49.7364 - ssim: 0.9958 - val_loss: 0.0021 - val_mae: 0.0021 - val_mse: 1.1597e-05 - val_psnr: 49.3652 - val_ssim: 0.9959 - learning_rate: 0.0010
# Epoch 130/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.0577e-05 - psnr: 49.7751 - ssim: 0.9958 - val_loss: 0.0022 - val_mae: 0.0022 - val_mse: 1.1641e-05 - val_psnr: 49.3485 - val_ssim: 0.9959 - learning_rate: 0.0010
# Epoch 131/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.0867e-05 - psnr: 49.6568 - ssim: 0.9959 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.0741e-05 - val_psnr: 49.6957 - val_ssim: 0.9959 - learning_rate: 0.0010
# Epoch 132/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0428e-05 - psnr: 49.8348 - ssim: 0.9958 - val_loss: 0.0022 - val_mae: 0.0022 - val_mse: 1.1270e-05 - val_psnr: 49.4879 - val_ssim: 0.9957 - learning_rate: 0.0010
# Epoch 133/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.0549e-05 - psnr: 49.7824 - ssim: 0.9958 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.0373e-05 - val_psnr: 49.8484 - val_ssim: 0.9959 - learning_rate: 0.0010
# Epoch 134/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.0517e-05 - psnr: 49.7982 - ssim: 0.9958 - val_loss: 0.0018 - val_mae: 0.0018 - val_mse: 9.5823e-06 - val_psnr: 50.1939 - val_ssim: 0.9959 - learning_rate: 0.0010
# Epoch 135/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0241e-05 - psnr: 49.9112 - ssim: 0.9959 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.1089e-05 - val_psnr: 49.5590 - val_ssim: 0.9958 - learning_rate: 0.0010
# Epoch 136/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.0953e-05 - psnr: 49.6301 - ssim: 0.9959 - val_loss: 0.0019 - val_mae: 0.0019 - val_mse: 9.8866e-06 - val_psnr: 50.0579 - val_ssim: 0.9959 - learning_rate: 0.0010
# Epoch 137/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0526e-05 - psnr: 49.7982 - ssim: 0.9959 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.0265e-05 - val_psnr: 49.8944 - val_ssim: 0.9959 - learning_rate: 0.0010
# Epoch 138/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 77s 114ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0395e-05 - psnr: 49.8510 - ssim: 0.9959 - val_loss: 0.0019 - val_mae: 0.0019 - val_mse: 9.9864e-06 - val_psnr: 50.0130 - val_ssim: 0.9958 - learning_rate: 0.0010
# Epoch 139/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0286e-05 - psnr: 49.9026 - ssim: 0.9959 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.0566e-05 - val_psnr: 49.7691 - val_ssim: 0.9958 - learning_rate: 0.0010
# Epoch 140/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0489e-05 - psnr: 49.8114 - ssim: 0.9959 - val_loss: 0.0019 - val_mae: 0.0019 - val_mse: 1.0062e-05 - val_psnr: 49.9811 - val_ssim: 0.9959 - learning_rate: 0.0010
# Epoch 141/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.0586e-05 - psnr: 49.7711 - ssim: 0.9959 - val_loss: 0.0021 - val_mae: 0.0021 - val_mse: 1.1198e-05 - val_psnr: 49.5173 - val_ssim: 0.9959 - learning_rate: 0.0010
# Epoch 142/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.0593e-05 - psnr: 49.7690 - ssim: 0.9959 - val_loss: 0.0022 - val_mae: 0.0022 - val_mse: 1.1883e-05 - val_psnr: 49.2583 - val_ssim: 0.9958 - learning_rate: 0.0010
# Epoch 143/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0288e-05 - psnr: 49.8950 - ssim: 0.9959 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.0564e-05 - val_psnr: 49.7687 - val_ssim: 0.9959 - learning_rate: 0.0010
# Epoch 144/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.0738e-05 - psnr: 49.7166 - ssim: 0.9959 - val_loss: 0.0028 - val_mae: 0.0028 - val_mse: 1.9727e-05 - val_psnr: 47.0564 - val_ssim: 0.9937 - learning_rate: 0.0010
# Epoch 145/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0789e-05 - psnr: 49.7307 - ssim: 0.9957 - val_loss: 0.0021 - val_mae: 0.0021 - val_mse: 1.1174e-05 - val_psnr: 49.5245 - val_ssim: 0.9956 - learning_rate: 0.0010
# Epoch 146/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0018 - mae: 0.0018 - mse: 1.0070e-05 - psnr: 49.9939 - ssim: 0.9959 - val_loss: 0.0021 - val_mae: 0.0021 - val_mse: 1.1738e-05 - val_psnr: 49.3114 - val_ssim: 0.9957 - learning_rate: 0.0010
# Epoch 147/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0446e-05 - psnr: 49.8287 - ssim: 0.9959 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.0472e-05 - val_psnr: 49.8081 - val_ssim: 0.9959 - learning_rate: 0.0010
# Epoch 148/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0377e-05 - psnr: 49.8559 - ssim: 0.9959 - val_loss: 0.0018 - val_mae: 0.0018 - val_mse: 9.6079e-06 - val_psnr: 50.1813 - val_ssim: 0.9959 - learning_rate: 0.0010
# Epoch 149/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0482e-05 - psnr: 49.8197 - ssim: 0.9959 - val_loss: 0.0018 - val_mae: 0.0018 - val_mse: 9.6113e-06 - val_psnr: 50.1801 - val_ssim: 0.9960 - learning_rate: 0.0010
# Epoch 150/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0056e-05 - psnr: 49.9929 - ssim: 0.9959 - val_loss: 0.0023 - val_mae: 0.0023 - val_mse: 1.2224e-05 - val_psnr: 49.1362 - val_ssim: 0.9960 - learning_rate: 0.0010
# Epoch 151/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0366e-05 - psnr: 49.8654 - ssim: 0.9959 - val_loss: 0.0018 - val_mae: 0.0018 - val_mse: 9.5431e-06 - val_psnr: 50.2120 - val_ssim: 0.9960 - learning_rate: 0.0010
# Epoch 152/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.0991e-05 - psnr: 49.7065 - ssim: 0.9958 - val_loss: 0.0018 - val_mae: 0.0018 - val_mse: 9.8017e-06 - val_psnr: 50.0951 - val_ssim: 0.9960 - learning_rate: 0.0010
# Epoch 153/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0176e-05 - psnr: 49.9440 - ssim: 0.9959 - val_loss: 0.0019 - val_mae: 0.0019 - val_mse: 9.8146e-06 - val_psnr: 50.0891 - val_ssim: 0.9960 - learning_rate: 0.0010
# Epoch 154/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0043e-05 - psnr: 49.9995 - ssim: 0.9959 - val_loss: 0.0021 - val_mae: 0.0021 - val_mse: 1.1314e-05 - val_psnr: 49.4714 - val_ssim: 0.9959 - learning_rate: 0.0010
# Epoch 155/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0069e-05 - psnr: 49.9877 - ssim: 0.9960 - val_loss: 0.0023 - val_mae: 0.0023 - val_mse: 1.2443e-05 - val_psnr: 49.0594 - val_ssim: 0.9960 - learning_rate: 0.0010
# Epoch 156/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.0773e-05 - psnr: 49.7096 - ssim: 0.9959 - val_loss: 0.0021 - val_mae: 0.0021 - val_mse: 1.0895e-05 - val_psnr: 49.6347 - val_ssim: 0.9960 - learning_rate: 0.0010
# Epoch 157/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0018 - mae: 0.0018 - mse: 9.7835e-06 - psnr: 50.1147 - ssim: 0.9960 - val_loss: 0.0018 - val_mae: 0.0018 - val_mse: 9.5232e-06 - val_psnr: 50.2194 - val_ssim: 0.9960 - learning_rate: 0.0010
# Epoch 158/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.0773e-05 - psnr: 49.7203 - ssim: 0.9958 - val_loss: 0.0018 - val_mae: 0.0018 - val_mse: 9.9479e-06 - val_psnr: 50.0310 - val_ssim: 0.9958 - learning_rate: 0.0010
# Epoch 159/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0136e-05 - psnr: 49.9646 - ssim: 0.9959 - val_loss: 0.0021 - val_mae: 0.0021 - val_mse: 1.1113e-05 - val_psnr: 49.5494 - val_ssim: 0.9960 - learning_rate: 0.0010
# Epoch 160/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0367e-05 - psnr: 49.8570 - ssim: 0.9959 - val_loss: 0.0018 - val_mae: 0.0018 - val_mse: 9.7508e-06 - val_psnr: 50.1177 - val_ssim: 0.9960 - learning_rate: 0.0010
# Epoch 161/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0019 - mae: 0.0019 - mse: 9.8695e-06 - psnr: 50.0693 - ssim: 0.9960 - val_loss: 0.0022 - val_mae: 0.0022 - val_mse: 1.1842e-05 - val_psnr: 49.2750 - val_ssim: 0.9960 - learning_rate: 0.0010
# Epoch 162/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.0656e-05 - psnr: 49.7477 - ssim: 0.9959 - val_loss: 0.0018 - val_mae: 0.0018 - val_mse: 9.6286e-06 - val_psnr: 50.1719 - val_ssim: 0.9960 - learning_rate: 0.0010
# Epoch 163/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0091e-05 - psnr: 49.9736 - ssim: 0.9960 - val_loss: 0.0016 - val_mae: 0.0016 - val_mse: 9.0850e-06 - val_psnr: 50.4255 - val_ssim: 0.9960 - learning_rate: 0.0010
# Epoch 164/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0277e-05 - psnr: 49.8969 - ssim: 0.9959 - val_loss: 0.0019 - val_mae: 0.0019 - val_mse: 1.0333e-05 - val_psnr: 49.8671 - val_ssim: 0.9961 - learning_rate: 0.0010
# Epoch 165/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0019 - mae: 0.0019 - mse: 9.9764e-06 - psnr: 50.0303 - ssim: 0.9960 - val_loss: 0.0019 - val_mae: 0.0019 - val_mse: 1.0588e-05 - val_psnr: 49.7620 - val_ssim: 0.9959 - learning_rate: 0.0010
# Epoch 166/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0417e-05 - psnr: 49.8460 - ssim: 0.9959 - val_loss: 0.0019 - val_mae: 0.0019 - val_mse: 1.0549e-05 - val_psnr: 49.7777 - val_ssim: 0.9960 - learning_rate: 0.0010
# Epoch 167/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0045e-05 - psnr: 50.0025 - ssim: 0.9959 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.0765e-05 - val_psnr: 49.6880 - val_ssim: 0.9960 - learning_rate: 0.0010
# Epoch 168/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0208e-05 - psnr: 49.9327 - ssim: 0.9960 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.1359e-05 - val_psnr: 49.4570 - val_ssim: 0.9960 - learning_rate: 0.0010
# Epoch 169/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0124e-05 - psnr: 49.9641 - ssim: 0.9960 - val_loss: 0.0019 - val_mae: 0.0019 - val_mse: 1.0195e-05 - val_psnr: 49.9246 - val_ssim: 0.9960 - learning_rate: 0.0010
# Epoch 170/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0122e-05 - psnr: 49.9579 - ssim: 0.9960 - val_loss: 0.0017 - val_mae: 0.0017 - val_mse: 9.4269e-06 - val_psnr: 50.2647 - val_ssim: 0.9960 - learning_rate: 0.0010
# Epoch 171/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0156e-05 - psnr: 49.9459 - ssim: 0.9959 - val_loss: 0.0018 - val_mae: 0.0018 - val_mse: 9.4890e-06 - val_psnr: 50.2350 - val_ssim: 0.9960 - learning_rate: 0.0010
# Epoch 172/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0018 - mae: 0.0018 - mse: 9.8112e-06 - psnr: 50.0985 - ssim: 0.9960 - val_loss: 0.0018 - val_mae: 0.0018 - val_mse: 9.7675e-06 - val_psnr: 50.1106 - val_ssim: 0.9959 - learning_rate: 0.0010
# Epoch 173/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0019 - mae: 0.0019 - mse: 9.9853e-06 - psnr: 50.0243 - ssim: 0.9960 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.0688e-05 - val_psnr: 49.7165 - val_ssim: 0.9959 - learning_rate: 0.0010
# Epoch 174/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0207e-05 - psnr: 49.9283 - ssim: 0.9960 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.0844e-05 - val_psnr: 49.6581 - val_ssim: 0.9960 - learning_rate: 0.0010
# Epoch 175/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0018 - mae: 0.0018 - mse: 9.6840e-06 - psnr: 50.1569 - ssim: 0.9960 - val_loss: 0.0018 - val_mae: 0.0018 - val_mse: 9.7490e-06 - val_psnr: 50.1188 - val_ssim: 0.9960 - learning_rate: 0.0010
# Epoch 176/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0044e-05 - psnr: 49.9950 - ssim: 0.9960 - val_loss: 0.0016 - val_mae: 0.0016 - val_mse: 9.0308e-06 - val_psnr: 50.4511 - val_ssim: 0.9961 - learning_rate: 0.0010
# Epoch 177/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0018 - mae: 0.0018 - mse: 9.6745e-06 - psnr: 50.1604 - ssim: 0.9960 - val_loss: 0.0022 - val_mae: 0.0022 - val_mse: 1.2125e-05 - val_psnr: 49.1694 - val_ssim: 0.9957 - learning_rate: 0.0010
# Epoch 178/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0019 - mae: 0.0019 - mse: 9.9883e-06 - psnr: 50.0193 - ssim: 0.9960 - val_loss: 0.0021 - val_mae: 0.0021 - val_mse: 1.1256e-05 - val_psnr: 49.4955 - val_ssim: 0.9961 - learning_rate: 0.0010
# Epoch 179/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0034e-05 - psnr: 50.0011 - ssim: 0.9959 - val_loss: 0.0019 - val_mae: 0.0019 - val_mse: 1.0577e-05 - val_psnr: 49.7634 - val_ssim: 0.9960 - learning_rate: 0.0010
# Epoch 180/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0250e-05 - psnr: 49.9144 - ssim: 0.9959 - val_loss: 0.0017 - val_mae: 0.0017 - val_mse: 9.0668e-06 - val_psnr: 50.4340 - val_ssim: 0.9960 - learning_rate: 0.0010
# Epoch 181/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0660e-05 - psnr: 49.7847 - ssim: 0.9958 - val_loss: 0.0016 - val_mae: 0.0016 - val_mse: 9.3003e-06 - val_psnr: 50.3234 - val_ssim: 0.9959 - learning_rate: 0.0010
# Epoch 182/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0136e-05 - psnr: 49.9567 - ssim: 0.9960 - val_loss: 0.0017 - val_mae: 0.0017 - val_mse: 9.1810e-06 - val_psnr: 50.3791 - val_ssim: 0.9961 - learning_rate: 0.0010
# Epoch 183/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0018 - mae: 0.0018 - mse: 9.8662e-06 - psnr: 50.0808 - ssim: 0.9960 - val_loss: 0.0017 - val_mae: 0.0017 - val_mse: 9.1005e-06 - val_psnr: 50.4184 - val_ssim: 0.9961 - learning_rate: 0.0010
# Epoch 184/250
# 671/672 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0019 - mae: 0.0019 - mse: 9.9083e-06 - psnr: 50.0532 - ssim: 0.9960
# Epoch 184: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0019 - mae: 0.0019 - mse: 9.9081e-06 - psnr: 50.0533 - ssim: 0.9960 - val_loss: 0.0019 - val_mae: 0.0019 - val_mse: 1.0145e-05 - val_psnr: 49.9459 - val_ssim: 0.9959 - learning_rate: 0.0010
# Epoch 185/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.5491e-06 - psnr: 50.6895 - ssim: 0.9961 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.4247e-06 - val_psnr: 50.7543 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 186/250
# ...
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.4470e-06 - psnr: 50.7413 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.3940e-06 - val_psnr: 50.7702 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 191/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3945e-06 - psnr: 50.7700 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.3882e-06 - val_psnr: 50.7733 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 192/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.4050e-06 - psnr: 50.7640 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.3870e-06 - val_psnr: 50.7738 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 193/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3868e-06 - psnr: 50.7724 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.3731e-06 - val_psnr: 50.7811 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 194/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.4158e-06 - psnr: 50.7581 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.3756e-06 - val_psnr: 50.7798 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 195/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3738e-06 - psnr: 50.7802 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.3777e-06 - val_psnr: 50.7787 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 196/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3966e-06 - psnr: 50.7678 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.3882e-06 - val_psnr: 50.7733 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 197/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3961e-06 - psnr: 50.7679 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.3649e-06 - val_psnr: 50.7853 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 198/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.4125e-06 - psnr: 50.7606 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.3544e-06 - val_psnr: 50.7909 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 199/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3893e-06 - psnr: 50.7717 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.3539e-06 - val_psnr: 50.7911 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 200/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3433e-06 - psnr: 50.7952 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.3505e-06 - val_psnr: 50.7929 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 201/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3664e-06 - psnr: 50.7834 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.3547e-06 - val_psnr: 50.7907 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 202/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3799e-06 - psnr: 50.7779 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.3719e-06 - val_psnr: 50.7817 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 203/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3782e-06 - psnr: 50.7780 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.3465e-06 - val_psnr: 50.7949 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 204/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3900e-06 - psnr: 50.7724 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.3454e-06 - val_psnr: 50.7955 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 205/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3881e-06 - psnr: 50.7731 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.3473e-06 - val_psnr: 50.7945 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 206/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3855e-06 - psnr: 50.7728 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.3465e-06 - val_psnr: 50.7949 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 207/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3597e-06 - psnr: 50.7867 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.3305e-06 - val_psnr: 50.8033 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 208/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3562e-06 - psnr: 50.7893 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.3323e-06 - val_psnr: 50.8023 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 209/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3208e-06 - psnr: 50.8074 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.3273e-06 - val_psnr: 50.8049 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 210/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3388e-06 - psnr: 50.7992 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.3855e-06 - val_psnr: 50.7747 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 211/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.4028e-06 - psnr: 50.7649 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.3386e-06 - val_psnr: 50.7990 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 212/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 77s 114ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3388e-06 - psnr: 50.7989 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.3457e-06 - val_psnr: 50.7953 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 213/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3489e-06 - psnr: 50.7929 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.3282e-06 - val_psnr: 50.8045 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 214/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3704e-06 - psnr: 50.7819 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.3176e-06 - val_psnr: 50.8100 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 215/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3698e-06 - psnr: 50.7814 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.3151e-06 - val_psnr: 50.8114 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 216/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3509e-06 - psnr: 50.7920 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.3250e-06 - val_psnr: 50.8061 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 217/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3044e-06 - psnr: 50.8163 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.3165e-06 - val_psnr: 50.8106 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 218/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3223e-06 - psnr: 50.8074 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.3194e-06 - val_psnr: 50.8091 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 219/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3319e-06 - psnr: 50.8017 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.3200e-06 - val_psnr: 50.8088 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 220/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3574e-06 - psnr: 50.7894 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.3052e-06 - val_psnr: 50.8166 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 221/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3503e-06 - psnr: 50.7918 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.3415e-06 - val_psnr: 50.7975 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 222/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3504e-06 - psnr: 50.7918 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.3096e-06 - val_psnr: 50.8142 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 223/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3415e-06 - psnr: 50.7966 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.3226e-06 - val_psnr: 50.8074 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 224/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3141e-06 - psnr: 50.8116 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.3074e-06 - val_psnr: 50.8154 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 225/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3039e-06 - psnr: 50.8162 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.3065e-06 - val_psnr: 50.8158 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 226/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3228e-06 - psnr: 50.8066 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.3078e-06 - val_psnr: 50.8151 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 227/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3357e-06 - psnr: 50.7995 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.3043e-06 - val_psnr: 50.8170 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 228/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.2964e-06 - psnr: 50.8204 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.2984e-06 - val_psnr: 50.8201 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 229/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3100e-06 - psnr: 50.8140 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.2943e-06 - val_psnr: 50.8222 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 230/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3361e-06 - psnr: 50.7986 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.2903e-06 - val_psnr: 50.8244 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 231/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.2969e-06 - psnr: 50.8206 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.2923e-06 - val_psnr: 50.8233 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 232/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 77s 114ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.2992e-06 - psnr: 50.8177 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.2949e-06 - val_psnr: 50.8219 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 233/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 77s 114ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3519e-06 - psnr: 50.7907 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.2872e-06 - val_psnr: 50.8260 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 234/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 77s 114ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3643e-06 - psnr: 50.7850 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.3710e-06 - val_psnr: 50.7823 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 235/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3525e-06 - psnr: 50.7909 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.2920e-06 - val_psnr: 50.8234 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 236/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3207e-06 - psnr: 50.8083 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.2796e-06 - val_psnr: 50.8300 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 237/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.2897e-06 - psnr: 50.8230 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.2800e-06 - val_psnr: 50.8297 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 238/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.2935e-06 - psnr: 50.8215 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.2844e-06 - val_psnr: 50.8274 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 239/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.2668e-06 - psnr: 50.8361 - ssim: 0.9963 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.2784e-06 - val_psnr: 50.8305 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 240/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3041e-06 - psnr: 50.8173 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.2794e-06 - val_psnr: 50.8300 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 241/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3044e-06 - psnr: 50.8164 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.2744e-06 - val_psnr: 50.8327 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 242/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.2944e-06 - psnr: 50.8203 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.2726e-06 - val_psnr: 50.8336 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 243/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3197e-06 - psnr: 50.8087 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.2765e-06 - val_psnr: 50.8316 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 244/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.2675e-06 - psnr: 50.8355 - ssim: 0.9963 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.2795e-06 - val_psnr: 50.8300 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 245/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3207e-06 - psnr: 50.8073 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.2665e-06 - val_psnr: 50.8368 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 246/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.2461e-06 - psnr: 50.8471 - ssim: 0.9963 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.2690e-06 - val_psnr: 50.8355 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 247/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.2874e-06 - psnr: 50.8260 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.2661e-06 - val_psnr: 50.8371 - val_ssim: 0.9963 - learning_rate: 1.0000e-04
# Epoch 248/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3094e-06 - psnr: 50.8135 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.2629e-06 - val_psnr: 50.8387 - val_ssim: 0.9963 - learning_rate: 1.0000e-04
# Epoch 249/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3000e-06 - psnr: 50.8176 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.2636e-06 - val_psnr: 50.8383 - val_ssim: 0.9963 - learning_rate: 1.0000e-04
# Epoch 250/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3160e-06 - psnr: 50.8092 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.2984e-06 - val_psnr: 50.8201 - val_ssim: 0.9963 - learning_rate: 1.0000e-04
# Training time: 19146.26 seconds

# %%
edsr_model = tf.keras.models.load_model('models/edsr_model_0_5to0_25_deg_dem_4c.keras', custom_objects={
    'psnr': psnr,
    'ssim': ssim,
    'residual_block': residual_block,
    'expand_static_data_dem_0_5': expand_static_data_dem_0_5,
    'expand_static_data_dem_0_25': expand_static_data_dem_0_25,
    'expand_static_aspect_0_5': expand_static_aspect_0_5,
    'expand_static_aspect_0_25': expand_static_aspect_0_25
}, safe_mode=False)

# %%
test_loss, test_psnr, test_ssim, test_mse, test_mae = edsr_model.evaluate(testX, testY)

print(f"Test Loss: {test_loss}")
print(f"Test PSNR: {test_psnr}")
print(f"Test SSIM: {test_ssim}")
print(f"Test MSE: {test_mse}")
print(f"Test MAE: {test_mae}")
# Out:
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 11s 76ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3640e-06 - psnr: 50.7858 - ssim: 0.9962
# Test Loss: 0.0014279786264523864
# Test PSNR: 50.79098892211914
# Test SSIM: 0.9962301254272461
# Test MSE: 8.353794328286313e-06
# Test MAE: 0.0014279787428677082

# %%
low_res_input = testX[1]
high_res_data = testY[1]
high_res_output = edsr_model.predict(np.expand_dims(low_res_input, axis=0))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step

# %%
plot_to_compare(low_res_input, np.squeeze(high_res_data),  np.squeeze(high_res_output), 'viridis')

# %%
### Europe
plot_to_compare(low_res_input[40:120, 80:200], np.squeeze(high_res_data)[80:240, 160:400],  np.squeeze(high_res_output)[80:240, 160:400], 'viridis')

# %%
### Greece
plot_to_compare(low_res_input[72:92, 156:180], np.squeeze(high_res_data)[144:184, 312:360],  np.squeeze(high_res_output)[144:184, 312:360], 'viridis')

# %%
# Compute per-pixel metrics
test_mse, test_mae, test_psnr, test_ssim = evaluate_per_pixel(edsr_model, testX, testY)

print("Per-pixel MSE shape:", test_mse.shape)
print("Per-pixel MAE shape:", test_mae.shape)
print("Per-pixel PSNR shape:", test_psnr.shape)
print("Per-pixel SSIM shape:", test_ssim.shape)

mean_mse = np.mean(test_mse)
mean_mae = np.mean(test_mae)
mean_psnr = np.mean(test_psnr)
mean_ssim = np.mean(test_ssim)

print("Mean Per-Pixel MSE:", mean_mse)
print("Mean Per-Pixel MAE:", mean_mae)
print("Mean Per-Pixel PSNR:", mean_psnr)
print("Mean Per-Pixel SSIM:", mean_ssim)
# Out:
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step
# Per-pixel MSE shape: (320, 580, 1)
# Per-pixel MAE shape: (320, 580, 1)
# Per-pixel PSNR shape: (320, 580, 1)
# Per-pixel SSIM shape: (320, 580, 1)
# Mean Per-Pixel MSE: 8.353789e-06
# Mean Per-Pixel MAE: 0.001427979
# Mean Per-Pixel PSNR: 56.87193
# Mean Per-Pixel SSIM: 0.99912125

# %%
plot_per_pixel_metrics(test_mse, test_mae, test_psnr, test_ssim)

# %%
degrees_mae = denormalize_mae(test_mae, global_Std)
print("Mean Per-Pixel Degrees MAE:", np.mean(degrees_mae))
print("Max Degrees MAE:", degrees_mae.max())
print("Min Degrees MAE:", degrees_mae.min())
plot_degrees_mae(degrees_mae)
# Out:
# Mean Per-Pixel Degrees MAE: 0.09175737
# Max Degrees MAE: 0.8628838
# Min Degrees MAE: 0.007884303

# %%
print("Mean Land-Pixels Degrees MAE:", mean_with_land_mask(degrees_mae, '0_25'))
print("Mean Land-Pixels MAE:", mean_with_land_mask(test_mae, '0_25'))
# Out:
# Mean Land-Pixels Degrees MAE: 0.14364234
# Mean Land-Pixels MAE: 0.0022354417
