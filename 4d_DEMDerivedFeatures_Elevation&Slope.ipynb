# %%
# Importing the drive module from google.colab library
from google.colab import drive

# Mounting the Google Drive to the Colab environment
drive.mount('/content/drive')

project_path = '/content/drive/My Drive/DEM_Aware_Downscaling/'

import os
os.chdir(project_path)
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import time
from utils.helpers_functions import read_dataset, z_score_normalize, denormalize_mae, mean_with_land_mask, compute_slope, compute_aspect
from utils.models_functions import psnr, ssim, save_history, save_model, train_model, load_model
from utils.display_functions import plot_history, plot_to_compare, plot_per_pixel_metrics, plot_degrees_mae
from utils.evaluation_functions import evaluate_per_pixel

# %%
dem_path='/content/drive/My Drive/DEM_Aware_Downscaling/dem_data/'
dates_path='/content/drive/My Drive/MSc_Thesis/input_data/index/'
lr_data_path='/content/drive/My Drive/MSc_Thesis/input_data/deg/0_5x0_5/'
hr_data_path='/content/drive/My Drive/MSc_Thesis/input_data/deg/0_25x0_25/'
global_mean = 286.307980744908
global_Std = 64.2568020375484
target_size = (320, 580)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, Add, LeakyReLU, Lambda, Conv2DTranspose, Concatenate
from tensorflow.keras.models import Model

# Load DEMs
dem_data_0_5 = np.load(dem_path + "dem_0_5.npy")
dem_data_0_25 = np.load(dem_path + "dem_0_25.npy")

# Compute slope
slope_0_5 = compute_slope(dem_data_0_5, 0.5)

slope_0_25 = compute_slope(dem_data_0_25, 0.25)

# Normalize all static features
dem_data_0_5 = z_score_normalize(dem_data_0_5, np.mean(dem_data_0_5), np.std(dem_data_0_5))
slope_0_5 = z_score_normalize(slope_0_5, np.mean(slope_0_5), np.std(slope_0_5))

dem_data_0_25 = z_score_normalize(dem_data_0_25, np.mean(dem_data_0_25), np.std(dem_data_0_25))
slope_0_25 = z_score_normalize(slope_0_25, np.mean(slope_0_25), np.std(slope_0_25))

# ---- Convert to Tensors and Expand ----
def to_tensor(x): return tf.expand_dims(tf.constant(x, dtype=tf.float32), axis=-1)

dem_tensor_0_5 = to_tensor(dem_data_0_5)
slope_tensor_0_5 = to_tensor(slope_0_5)

dem_tensor_0_25 = to_tensor(dem_data_0_25)
slope_tensor_0_25 = to_tensor(slope_0_25)

def expand_static_data_dem_0_5(x):
    batch_size = tf.shape(x)[0]
    return tf.tile(tf.expand_dims(dem_tensor_0_5, 0), [batch_size, 1, 1, 1])

def expand_static_data_dem_0_25(x):
    batch_size = tf.shape(x)[0]
    return tf.tile(tf.expand_dims(dem_tensor_0_25, 0), [batch_size, 1, 1, 1])

def expand_static_slope_0_5(x):
    batch_size = tf.shape(x)[0]
    return tf.tile(tf.expand_dims(slope_tensor_0_5, 0), [batch_size, 1, 1, 1])

def expand_static_slope_0_25(x):
    batch_size = tf.shape(x)[0]
    return tf.tile(tf.expand_dims(slope_tensor_0_25, 0), [batch_size, 1, 1, 1])

# ---- Residual Block ----
def residual_block(x, filters=32, kernel_size=3, scaling=0.1):
    res = Conv2D(filters, kernel_size, padding='same')(x)
    res = LeakyReLU(alpha=0.2)(res)
    res = Conv2D(filters, kernel_size, padding='same')(res)
    res = Lambda(lambda t: t * scaling)(res)
    return Add()([x, res])

# ---- Model ----
def create_edsr():
    input_img = Input(shape=(160, 290, 1))  # Low-resolution input

    # --- Low-Res Static Features (0.5°) ---
    static_low = Concatenate()([
        Lambda(expand_static_data_dem_0_5, output_shape=(160, 290, 1))(input_img),
        Lambda(expand_static_slope_0_5, output_shape=(160, 290, 1))(input_img)
    ])
    x = Concatenate()([input_img, static_low])

    # Initial Conv Layer
    initial_conv = Conv2D(filters=32, kernel_size=3, padding='same')(x)

    # Residual Blocks
    x = residual_block(initial_conv, filters=32)
    x = residual_block(x, filters=32)
    x = residual_block(x, filters=32)
    x = residual_block(x, filters=32)

    x = Conv2D(filters=32, kernel_size=3, padding='same')(x)
    x = Add()([x, initial_conv])

    # Upsample (learned)
    x = Conv2DTranspose(filters=32, kernel_size=3, strides=2, padding='same')(x)

    # --- High-Res Static Features (0.25°) ---
    static_high = Concatenate()([
        Lambda(expand_static_data_dem_0_25, output_shape=(320, 580, 1))(input_img),
        Lambda(expand_static_slope_0_25, output_shape=(320, 580, 1))(input_img)
    ])
    x = Concatenate()([x, static_high])

    # Fusion Layers
    # x = Conv2D(filters=64, kernel_size=3, padding='same', activation='relu')(x)
    x = Conv2D(filters=32, kernel_size=3, padding='same', activation='relu')(x)
    x = Conv2D(filters=16, kernel_size=3, padding='same', activation='relu')(x)
    # x = Conv2D(filters=8, kernel_size=3, padding='same', activation='relu')(x)

    # Final Conv Layer (Reduces to 1 Output Channel)
    output_img = Conv2D(filters=1, kernel_size=3, padding='same')(x)

    # Model Compilation
    model = Model(inputs=input_img, outputs=output_img)
    model.compile(optimizer='adam', loss='mae', metrics=[psnr, ssim, 'mse', 'mae'])

    return model

# %%
trainX, valX, testX, trainY, valY, testY, trainDates, valDates, testDates = read_dataset(dates_path, lr_data_path, hr_data_path, 'all', 2000, 2020, global_mean, global_Std)

print(trainX.shape)
print(trainY.shape)
print(valX.shape)
print(valY.shape)
print(testX.shape)
print(testY.shape)
# Out:
# (21478, 160, 290, 1)
# (21478, 320, 580, 1)
# (4602, 160, 290, 1)
# (4602, 320, 580, 1)
# (4604, 160, 290, 1)
# (4604, 320, 580, 1)

# %%
# Initialize the model
edsr_model = create_edsr()
edsr_model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 160, 290,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda (Lambda)     │ (None, 160, 290,  │          0 │ input_layer[0][0] │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_1 (Lambda)   │ (None, 160, 290,  │          0 │ input_layer[0][0] │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 160, 290,  │          0 │ lambda[0][0],     │
# │ (Concatenate)       │ 2)                │            │ lambda_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 160, 290,  │          0 │ input_layer[0][0… │
# │ (Concatenate)       │ 3)                │            │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 160, 290,  │        896 │ concatenate_1[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 160, 290,  │      9,248 │ conv2d[0][0]      │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu         │ (None, 160, 290,  │          0 │ conv2d_1[0][0]    │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 160, 290,  │      9,248 │ leaky_re_lu[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_2 (Lambda)   │ (None, 160, 290,  │          0 │ conv2d_2[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 160, 290,  │          0 │ conv2d[0][0],     │
# │                     │ 32)               │            │ lambda_2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 160, 290,  │      9,248 │ add[0][0]         │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_1       │ (None, 160, 290,  │          0 │ conv2d_3[0][0]    │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 160, 290,  │      9,248 │ leaky_re_lu_1[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_3 (Lambda)   │ (None, 160, 290,  │          0 │ conv2d_4[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 160, 290,  │          0 │ add[0][0],        │
# │                     │ 32)               │            │ lambda_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 160, 290,  │      9,248 │ add_1[0][0]       │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_2       │ (None, 160, 290,  │          0 │ conv2d_5[0][0]    │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 160, 290,  │      9,248 │ leaky_re_lu_2[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_4 (Lambda)   │ (None, 160, 290,  │          0 │ conv2d_6[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 160, 290,  │          0 │ add_1[0][0],      │
# │                     │ 32)               │            │ lambda_4[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 160, 290,  │      9,248 │ add_2[0][0]       │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_3       │ (None, 160, 290,  │          0 │ conv2d_7[0][0]    │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 160, 290,  │      9,248 │ leaky_re_lu_3[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_5 (Lambda)   │ (None, 160, 290,  │          0 │ conv2d_8[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 160, 290,  │          0 │ add_2[0][0],      │
# │                     │ 32)               │            │ lambda_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 160, 290,  │      9,248 │ add_3[0][0]       │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 160, 290,  │          0 │ conv2d_9[0][0],   │
# │                     │ 32)               │            │ conv2d[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_6 (Lambda)   │ (None, 320, 580,  │          0 │ input_layer[0][0] │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_7 (Lambda)   │ (None, 320, 580,  │          0 │ input_layer[0][0] │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 320, 580,  │      9,248 │ add_4[0][0]       │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 320, 580,  │          0 │ lambda_6[0][0],   │
# │ (Concatenate)       │ 2)                │            │ lambda_7[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 320, 580,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 34)               │            │ concatenate_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 320, 580,  │      9,824 │ concatenate_3[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 320, 580,  │      4,624 │ conv2d_10[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 320, 580,  │        145 │ conv2d_11[0][0]   │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 107,969 (421.75 KB)
#  Trainable params: 107,969 (421.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
start_time = time.time()
history = train_model(edsr_model, trainX, trainY, valX, valY, 250, 32, True, True, 100, 70)
end_time = time.time()

# Print the time taken
print(f"Training time: {end_time - start_time:.2f} seconds")

save_history(history.history, 'models/history_0_5to0_25_deg_dem_4d.pkl')
plot_history(history.history)

save_model(edsr_model, 'models/edsr_model_0_5to0_25_deg_dem_4d.keras')
# Out:
# Epoch 1/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 138s 156ms/step - loss: 0.0260 - mae: 0.0260 - mse: 0.0044 - psnr: 29.4886 - ssim: 0.8024 - val_loss: 0.0080 - val_mae: 0.0080 - val_mse: 2.3309e-04 - val_psnr: 36.3294 - val_ssim: 0.9588 - learning_rate: 0.0010
# Epoch 2/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0074 - mae: 0.0074 - mse: 1.7878e-04 - psnr: 37.5996 - ssim: 0.9662 - val_loss: 0.0051 - val_mae: 0.0051 - val_mse: 9.1556e-05 - val_psnr: 40.3857 - val_ssim: 0.9768 - learning_rate: 0.0010
# Epoch 3/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0056 - mae: 0.0056 - mse: 9.3392e-05 - psnr: 40.3565 - ssim: 0.9786 - val_loss: 0.0053 - val_mae: 0.0053 - val_mse: 7.9830e-05 - val_psnr: 40.9815 - val_ssim: 0.9835 - learning_rate: 0.0010
# Epoch 4/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0052 - mae: 0.0052 - mse: 7.2939e-05 - psnr: 41.4613 - ssim: 0.9839 - val_loss: 0.0047 - val_mae: 0.0047 - val_mse: 6.2219e-05 - val_psnr: 42.0628 - val_ssim: 0.9859 - learning_rate: 0.0010
# Epoch 5/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0046 - mae: 0.0046 - mse: 5.7607e-05 - psnr: 42.4725 - ssim: 0.9866 - val_loss: 0.0039 - val_mae: 0.0039 - val_mse: 4.2505e-05 - val_psnr: 43.7173 - val_ssim: 0.9881 - learning_rate: 0.0010
# Epoch 6/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0041 - mae: 0.0041 - mse: 4.1585e-05 - psnr: 43.8801 - ssim: 0.9879 - val_loss: 0.0038 - val_mae: 0.0038 - val_mse: 3.9768e-05 - val_psnr: 44.0070 - val_ssim: 0.9876 - learning_rate: 0.0010
# Epoch 7/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0041 - mae: 0.0041 - mse: 4.0026e-05 - psnr: 44.0925 - ssim: 0.9890 - val_loss: 0.0041 - val_mae: 0.0041 - val_mse: 3.8040e-05 - val_psnr: 44.2036 - val_ssim: 0.9905 - learning_rate: 0.0010
# Epoch 8/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0039 - mae: 0.0039 - mse: 3.6964e-05 - psnr: 44.4541 - ssim: 0.9896 - val_loss: 0.0036 - val_mae: 0.0036 - val_mse: 2.9584e-05 - val_psnr: 45.2914 - val_ssim: 0.9902 - learning_rate: 0.0010
# Epoch 9/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0036 - mae: 0.0036 - mse: 3.1690e-05 - psnr: 45.0633 - ssim: 0.9902 - val_loss: 0.0041 - val_mae: 0.0041 - val_mse: 3.7164e-05 - val_psnr: 44.3048 - val_ssim: 0.9909 - learning_rate: 0.0010
# Epoch 10/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0035 - mae: 0.0035 - mse: 2.9943e-05 - psnr: 45.2757 - ssim: 0.9909 - val_loss: 0.0030 - val_mae: 0.0030 - val_mse: 2.4337e-05 - val_psnr: 46.1398 - val_ssim: 0.9917 - learning_rate: 0.0010
# Epoch 11/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0034 - mae: 0.0034 - mse: 2.8396e-05 - psnr: 45.5144 - ssim: 0.9910 - val_loss: 0.0035 - val_mae: 0.0035 - val_mse: 2.8711e-05 - val_psnr: 45.4225 - val_ssim: 0.9917 - learning_rate: 0.0010
# Epoch 12/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0034 - mae: 0.0034 - mse: 2.7945e-05 - psnr: 45.5784 - ssim: 0.9915 - val_loss: 0.0029 - val_mae: 0.0029 - val_mse: 2.4237e-05 - val_psnr: 46.1575 - val_ssim: 0.9911 - learning_rate: 0.0010
# Epoch 13/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0032 - mae: 0.0032 - mse: 2.6143e-05 - psnr: 45.8683 - ssim: 0.9916 - val_loss: 0.0030 - val_mae: 0.0030 - val_mse: 2.3433e-05 - val_psnr: 46.3054 - val_ssim: 0.9919 - learning_rate: 0.0010
# Epoch 14/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0031 - mae: 0.0031 - mse: 2.4180e-05 - psnr: 46.1938 - ssim: 0.9918 - val_loss: 0.0029 - val_mae: 0.0029 - val_mse: 2.1365e-05 - val_psnr: 46.7055 - val_ssim: 0.9921 - learning_rate: 0.0010
# Epoch 15/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0030 - mae: 0.0030 - mse: 2.4116e-05 - psnr: 46.2298 - ssim: 0.9920 - val_loss: 0.0026 - val_mae: 0.0026 - val_mse: 1.9670e-05 - val_psnr: 47.0658 - val_ssim: 0.9926 - learning_rate: 0.0010
# Epoch 16/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0031 - mae: 0.0031 - mse: 2.3296e-05 - psnr: 46.3512 - ssim: 0.9922 - val_loss: 0.0030 - val_mae: 0.0030 - val_mse: 2.3120e-05 - val_psnr: 46.3640 - val_ssim: 0.9923 - learning_rate: 0.0010
# Epoch 17/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0029 - mae: 0.0029 - mse: 2.1390e-05 - psnr: 46.7246 - ssim: 0.9924 - val_loss: 0.0035 - val_mae: 0.0035 - val_mse: 2.5172e-05 - val_psnr: 45.9944 - val_ssim: 0.9929 - learning_rate: 0.0010
# Epoch 18/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0030 - mae: 0.0030 - mse: 2.1971e-05 - psnr: 46.6081 - ssim: 0.9928 - val_loss: 0.0031 - val_mae: 0.0031 - val_mse: 2.2129e-05 - val_psnr: 46.5538 - val_ssim: 0.9930 - learning_rate: 0.0010
# Epoch 19/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0028 - mae: 0.0028 - mse: 2.0884e-05 - psnr: 46.8237 - ssim: 0.9928 - val_loss: 0.0031 - val_mae: 0.0031 - val_mse: 2.2066e-05 - val_psnr: 46.5680 - val_ssim: 0.9933 - learning_rate: 0.0010
# Epoch 20/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0027 - mae: 0.0027 - mse: 2.0264e-05 - psnr: 46.9717 - ssim: 0.9928 - val_loss: 0.0028 - val_mae: 0.0028 - val_mse: 1.9377e-05 - val_psnr: 47.1311 - val_ssim: 0.9933 - learning_rate: 0.0010
# Epoch 21/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0027 - mae: 0.0027 - mse: 1.9830e-05 - psnr: 47.0576 - ssim: 0.9929 - val_loss: 0.0027 - val_mae: 0.0027 - val_mse: 2.0946e-05 - val_psnr: 46.7912 - val_ssim: 0.9921 - learning_rate: 0.0010
# Epoch 22/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0028 - mae: 0.0028 - mse: 2.0633e-05 - psnr: 46.8860 - ssim: 0.9927 - val_loss: 0.0026 - val_mae: 0.0026 - val_mse: 1.8581e-05 - val_psnr: 47.3129 - val_ssim: 0.9935 - learning_rate: 0.0010
# Epoch 23/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0027 - mae: 0.0027 - mse: 1.8976e-05 - psnr: 47.2337 - ssim: 0.9932 - val_loss: 0.0028 - val_mae: 0.0028 - val_mse: 1.8592e-05 - val_psnr: 47.3104 - val_ssim: 0.9938 - learning_rate: 0.0010
# Epoch 24/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0027 - mae: 0.0027 - mse: 1.9115e-05 - psnr: 47.2447 - ssim: 0.9933 - val_loss: 0.0023 - val_mae: 0.0023 - val_mse: 1.6341e-05 - val_psnr: 47.8711 - val_ssim: 0.9935 - learning_rate: 0.0010
# Epoch 25/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0025 - mae: 0.0025 - mse: 1.7361e-05 - psnr: 47.6248 - ssim: 0.9936 - val_loss: 0.0027 - val_mae: 0.0027 - val_mse: 1.8373e-05 - val_psnr: 47.3632 - val_ssim: 0.9939 - learning_rate: 0.0010
# Epoch 26/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0026 - mae: 0.0026 - mse: 1.7923e-05 - psnr: 47.4945 - ssim: 0.9934 - val_loss: 0.0022 - val_mae: 0.0022 - val_mse: 1.5136e-05 - val_psnr: 48.2040 - val_ssim: 0.9940 - learning_rate: 0.0010
# Epoch 27/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0025 - mae: 0.0025 - mse: 1.6717e-05 - psnr: 47.7896 - ssim: 0.9938 - val_loss: 0.0025 - val_mae: 0.0025 - val_mse: 1.6845e-05 - val_psnr: 47.7397 - val_ssim: 0.9937 - learning_rate: 0.0010
# Epoch 28/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0024 - mae: 0.0024 - mse: 1.6229e-05 - psnr: 47.9136 - ssim: 0.9939 - val_loss: 0.0026 - val_mae: 0.0026 - val_mse: 1.7091e-05 - val_psnr: 47.6782 - val_ssim: 0.9942 - learning_rate: 0.0010
# Epoch 29/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0025 - mae: 0.0025 - mse: 1.6772e-05 - psnr: 47.7743 - ssim: 0.9938 - val_loss: 0.0025 - val_mae: 0.0025 - val_mse: 1.6310e-05 - val_psnr: 47.8792 - val_ssim: 0.9939 - learning_rate: 0.0010
# Epoch 30/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0024 - mae: 0.0024 - mse: 1.6142e-05 - psnr: 47.9390 - ssim: 0.9941 - val_loss: 0.0021 - val_mae: 0.0021 - val_mse: 1.4043e-05 - val_psnr: 48.5299 - val_ssim: 0.9943 - learning_rate: 0.0010
# Epoch 31/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0024 - mae: 0.0024 - mse: 1.5781e-05 - psnr: 48.0380 - ssim: 0.9941 - val_loss: 0.0027 - val_mae: 0.0027 - val_mse: 1.7016e-05 - val_psnr: 47.6955 - val_ssim: 0.9936 - learning_rate: 0.0010
# Epoch 32/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0025 - mae: 0.0025 - mse: 1.6138e-05 - psnr: 47.9366 - ssim: 0.9939 - val_loss: 0.0023 - val_mae: 0.0023 - val_mse: 1.4676e-05 - val_psnr: 48.3389 - val_ssim: 0.9944 - learning_rate: 0.0010
# Epoch 33/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0024 - mae: 0.0024 - mse: 1.5301e-05 - psnr: 48.1722 - ssim: 0.9943 - val_loss: 0.0024 - val_mae: 0.0024 - val_mse: 1.5173e-05 - val_psnr: 48.1953 - val_ssim: 0.9945 - learning_rate: 0.0010
# Epoch 34/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0025 - mae: 0.0025 - mse: 1.7150e-05 - psnr: 47.7970 - ssim: 0.9937 - val_loss: 0.0027 - val_mae: 0.0027 - val_mse: 1.7530e-05 - val_psnr: 47.5662 - val_ssim: 0.9936 - learning_rate: 0.0010
# Epoch 35/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0025 - mae: 0.0025 - mse: 1.5779e-05 - psnr: 48.0354 - ssim: 0.9940 - val_loss: 0.0025 - val_mae: 0.0025 - val_mse: 1.5222e-05 - val_psnr: 48.1814 - val_ssim: 0.9944 - learning_rate: 0.0010
# Epoch 36/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0024 - mae: 0.0024 - mse: 1.5047e-05 - psnr: 48.2405 - ssim: 0.9943 - val_loss: 0.0024 - val_mae: 0.0024 - val_mse: 1.4902e-05 - val_psnr: 48.2721 - val_ssim: 0.9943 - learning_rate: 0.0010
# Epoch 37/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0024 - mae: 0.0024 - mse: 1.5033e-05 - psnr: 48.2456 - ssim: 0.9943 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.3232e-05 - val_psnr: 48.7893 - val_ssim: 0.9946 - learning_rate: 0.0010
# Epoch 38/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0022 - mae: 0.0022 - mse: 1.4159e-05 - psnr: 48.5059 - ssim: 0.9945 - val_loss: 0.0026 - val_mae: 0.0026 - val_mse: 1.5920e-05 - val_psnr: 47.9855 - val_ssim: 0.9942 - learning_rate: 0.0010
# Epoch 39/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0023 - mae: 0.0023 - mse: 1.4442e-05 - psnr: 48.4192 - ssim: 0.9945 - val_loss: 0.0026 - val_mae: 0.0026 - val_mse: 1.5586e-05 - val_psnr: 48.0781 - val_ssim: 0.9944 - learning_rate: 0.0010
# Epoch 40/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0021 - mae: 0.0021 - mse: 1.3575e-05 - psnr: 48.6912 - ssim: 0.9947 - val_loss: 0.0022 - val_mae: 0.0022 - val_mse: 1.3951e-05 - val_psnr: 48.5614 - val_ssim: 0.9949 - learning_rate: 0.0010
# Epoch 41/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0023 - mae: 0.0023 - mse: 1.4468e-05 - psnr: 48.4165 - ssim: 0.9946 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.3094e-05 - val_psnr: 48.8345 - val_ssim: 0.9945 - learning_rate: 0.0010
# Epoch 42/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0022 - mae: 0.0022 - mse: 1.3800e-05 - psnr: 48.6168 - ssim: 0.9948 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.2977e-05 - val_psnr: 48.8734 - val_ssim: 0.9945 - learning_rate: 0.0010
# Epoch 43/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0022 - mae: 0.0022 - mse: 1.3556e-05 - psnr: 48.7144 - ssim: 0.9948 - val_loss: 0.0031 - val_mae: 0.0031 - val_mse: 3.0286e-05 - val_psnr: 45.1903 - val_ssim: 0.9913 - learning_rate: 0.0010
# Epoch 44/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0024 - mae: 0.0024 - mse: 1.7784e-05 - psnr: 47.6320 - ssim: 0.9935 - val_loss: 0.0024 - val_mae: 0.0024 - val_mse: 1.4846e-05 - val_psnr: 48.2894 - val_ssim: 0.9948 - learning_rate: 0.0010
# Epoch 45/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0022 - mae: 0.0022 - mse: 1.4083e-05 - psnr: 48.5292 - ssim: 0.9946 - val_loss: 0.0021 - val_mae: 0.0021 - val_mse: 1.3467e-05 - val_psnr: 48.7143 - val_ssim: 0.9948 - learning_rate: 0.0010
# Epoch 46/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0023 - mae: 0.0023 - mse: 1.4181e-05 - psnr: 48.5096 - ssim: 0.9946 - val_loss: 0.0023 - val_mae: 0.0023 - val_mse: 1.3574e-05 - val_psnr: 48.6775 - val_ssim: 0.9949 - learning_rate: 0.0010
# Epoch 47/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0022 - mae: 0.0022 - mse: 1.3438e-05 - psnr: 48.7338 - ssim: 0.9947 - val_loss: 0.0024 - val_mae: 0.0024 - val_mse: 1.5191e-05 - val_psnr: 48.1912 - val_ssim: 0.9949 - learning_rate: 0.0010
# Epoch 48/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0023 - mae: 0.0023 - mse: 1.3920e-05 - psnr: 48.5807 - ssim: 0.9947 - val_loss: 0.0024 - val_mae: 0.0024 - val_mse: 1.4217e-05 - val_psnr: 48.4774 - val_ssim: 0.9947 - learning_rate: 0.0010
# Epoch 49/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0022 - mae: 0.0022 - mse: 1.3523e-05 - psnr: 48.7042 - ssim: 0.9947 - val_loss: 0.0022 - val_mae: 0.0022 - val_mse: 1.3447e-05 - val_psnr: 48.7195 - val_ssim: 0.9947 - learning_rate: 0.0010
# Epoch 50/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0022 - mae: 0.0022 - mse: 1.3340e-05 - psnr: 48.7601 - ssim: 0.9948 - val_loss: 0.0021 - val_mae: 0.0021 - val_mse: 1.3346e-05 - val_psnr: 48.7542 - val_ssim: 0.9950 - learning_rate: 0.0010
# Epoch 51/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0022 - mae: 0.0022 - mse: 1.3127e-05 - psnr: 48.8331 - ssim: 0.9950 - val_loss: 0.0024 - val_mae: 0.0024 - val_mse: 1.4084e-05 - val_psnr: 48.5179 - val_ssim: 0.9947 - learning_rate: 0.0010
# Epoch 52/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0022 - mae: 0.0022 - mse: 1.3332e-05 - psnr: 48.7648 - ssim: 0.9948 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.2085e-05 - val_psnr: 49.1828 - val_ssim: 0.9950 - learning_rate: 0.0010
# Epoch 53/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.2297e-05 - psnr: 49.1280 - ssim: 0.9950 - val_loss: 0.0025 - val_mae: 0.0025 - val_mse: 1.6030e-05 - val_psnr: 47.9604 - val_ssim: 0.9950 - learning_rate: 0.0010
# Epoch 54/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0023 - mae: 0.0023 - mse: 1.4503e-05 - psnr: 48.4545 - ssim: 0.9946 - val_loss: 0.0025 - val_mae: 0.0025 - val_mse: 1.5158e-05 - val_psnr: 48.2022 - val_ssim: 0.9952 - learning_rate: 0.0010
# Epoch 55/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0021 - mae: 0.0021 - mse: 1.2812e-05 - psnr: 48.9448 - ssim: 0.9951 - val_loss: 0.0021 - val_mae: 0.0021 - val_mse: 1.2339e-05 - val_psnr: 49.0951 - val_ssim: 0.9952 - learning_rate: 0.0010
# Epoch 56/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0022 - mae: 0.0022 - mse: 1.4437e-05 - psnr: 48.5421 - ssim: 0.9946 - val_loss: 0.0021 - val_mae: 0.0021 - val_mse: 1.2233e-05 - val_psnr: 49.1315 - val_ssim: 0.9952 - learning_rate: 0.0010
# Epoch 57/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0022 - mae: 0.0022 - mse: 1.2703e-05 - psnr: 48.9751 - ssim: 0.9951 - val_loss: 0.0023 - val_mae: 0.0023 - val_mse: 1.3477e-05 - val_psnr: 48.7106 - val_ssim: 0.9949 - learning_rate: 0.0010
# Epoch 58/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0021 - mae: 0.0021 - mse: 1.2412e-05 - psnr: 49.0746 - ssim: 0.9951 - val_loss: 0.0023 - val_mae: 0.0023 - val_mse: 1.3414e-05 - val_psnr: 48.7297 - val_ssim: 0.9953 - learning_rate: 0.0010
# Epoch 59/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0022 - mae: 0.0022 - mse: 1.3022e-05 - psnr: 48.8794 - ssim: 0.9950 - val_loss: 0.0031 - val_mae: 0.0031 - val_mse: 2.0854e-05 - val_psnr: 46.8119 - val_ssim: 0.9927 - learning_rate: 0.0010
# Epoch 60/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0022 - mae: 0.0022 - mse: 1.3445e-05 - psnr: 48.7525 - ssim: 0.9948 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.1905e-05 - val_psnr: 49.2495 - val_ssim: 0.9953 - learning_rate: 0.0010
# Epoch 61/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0022 - mae: 0.0022 - mse: 1.2653e-05 - psnr: 48.9895 - ssim: 0.9951 - val_loss: 0.0023 - val_mae: 0.0023 - val_mse: 1.3135e-05 - val_psnr: 48.8229 - val_ssim: 0.9952 - learning_rate: 0.0010
# Epoch 62/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0021 - mae: 0.0021 - mse: 1.2478e-05 - psnr: 49.0521 - ssim: 0.9952 - val_loss: 0.0019 - val_mae: 0.0019 - val_mse: 1.2357e-05 - val_psnr: 49.0864 - val_ssim: 0.9948 - learning_rate: 0.0010
# Epoch 63/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0021 - mae: 0.0021 - mse: 1.2478e-05 - psnr: 49.0550 - ssim: 0.9953 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.2010e-05 - val_psnr: 49.2125 - val_ssim: 0.9953 - learning_rate: 0.0010
# Epoch 64/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0023 - mae: 0.0023 - mse: 1.4248e-05 - psnr: 48.6118 - ssim: 0.9946 - val_loss: 0.0019 - val_mae: 0.0019 - val_mse: 1.1150e-05 - val_psnr: 49.5332 - val_ssim: 0.9954 - learning_rate: 0.0010
# Epoch 65/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.1519e-05 - psnr: 49.4000 - ssim: 0.9953 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.1710e-05 - val_psnr: 49.3202 - val_ssim: 0.9954 - learning_rate: 0.0010
# Epoch 66/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0021 - mae: 0.0021 - mse: 1.2300e-05 - psnr: 49.1191 - ssim: 0.9953 - val_loss: 0.0018 - val_mae: 0.0018 - val_mse: 1.1061e-05 - val_psnr: 49.5702 - val_ssim: 0.9954 - learning_rate: 0.0010
# Epoch 67/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.1887e-05 - psnr: 49.2613 - ssim: 0.9954 - val_loss: 0.0023 - val_mae: 0.0023 - val_mse: 1.3108e-05 - val_psnr: 48.8319 - val_ssim: 0.9954 - learning_rate: 0.0010
# Epoch 68/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0018 - mae: 0.0018 - mse: 1.1309e-05 - psnr: 49.5095 - ssim: 0.9953 - val_loss: 0.0025 - val_mae: 0.0025 - val_mse: 1.3595e-05 - val_psnr: 48.6704 - val_ssim: 0.9949 - learning_rate: 0.0010
# Epoch 69/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0023 - mae: 0.0023 - mse: 1.3421e-05 - psnr: 48.7511 - ssim: 0.9950 - val_loss: 0.0024 - val_mae: 0.0024 - val_mse: 1.3360e-05 - val_psnr: 48.7465 - val_ssim: 0.9948 - learning_rate: 0.0010
# Epoch 70/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0021 - mae: 0.0021 - mse: 1.2279e-05 - psnr: 49.1252 - ssim: 0.9952 - val_loss: 0.0021 - val_mae: 0.0021 - val_mse: 1.1969e-05 - val_psnr: 49.2254 - val_ssim: 0.9954 - learning_rate: 0.0010
# Epoch 71/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0021 - mae: 0.0021 - mse: 1.2028e-05 - psnr: 49.2140 - ssim: 0.9954 - val_loss: 0.0023 - val_mae: 0.0023 - val_mse: 1.3111e-05 - val_psnr: 48.8289 - val_ssim: 0.9951 - learning_rate: 0.0010
# Epoch 72/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0021 - mae: 0.0021 - mse: 1.2008e-05 - psnr: 49.2224 - ssim: 0.9953 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.1577e-05 - val_psnr: 49.3707 - val_ssim: 0.9955 - learning_rate: 0.0010
# Epoch 73/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0022 - mae: 0.0022 - mse: 1.4096e-05 - psnr: 48.7548 - ssim: 0.9947 - val_loss: 0.0021 - val_mae: 0.0021 - val_mse: 1.2025e-05 - val_psnr: 49.2076 - val_ssim: 0.9955 - learning_rate: 0.0010
# Epoch 74/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0021 - mae: 0.0021 - mse: 1.2020e-05 - psnr: 49.2178 - ssim: 0.9953 - val_loss: 0.0019 - val_mae: 0.0019 - val_mse: 1.1034e-05 - val_psnr: 49.5785 - val_ssim: 0.9955 - learning_rate: 0.0010
# Epoch 75/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.1337e-05 - psnr: 49.4737 - ssim: 0.9954 - val_loss: 0.0023 - val_mae: 0.0023 - val_mse: 1.3430e-05 - val_psnr: 48.7273 - val_ssim: 0.9955 - learning_rate: 0.0010
# Epoch 76/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.1209e-05 - psnr: 49.5342 - ssim: 0.9955 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.1867e-05 - val_psnr: 49.2648 - val_ssim: 0.9954 - learning_rate: 0.0010
# Epoch 77/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.1638e-05 - psnr: 49.3649 - ssim: 0.9954 - val_loss: 0.0021 - val_mae: 0.0021 - val_mse: 1.1567e-05 - val_psnr: 49.3734 - val_ssim: 0.9956 - learning_rate: 0.0010
# Epoch 78/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0021 - mae: 0.0021 - mse: 1.1951e-05 - psnr: 49.2510 - ssim: 0.9954 - val_loss: 0.0019 - val_mae: 0.0019 - val_mse: 1.0778e-05 - val_psnr: 49.6812 - val_ssim: 0.9956 - learning_rate: 0.0010
# Epoch 79/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0021 - mae: 0.0021 - mse: 1.1738e-05 - psnr: 49.3238 - ssim: 0.9954 - val_loss: 0.0022 - val_mae: 0.0022 - val_mse: 1.2208e-05 - val_psnr: 49.1411 - val_ssim: 0.9953 - learning_rate: 0.0010
# Epoch 80/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.1500e-05 - psnr: 49.4075 - ssim: 0.9955 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.1194e-05 - val_psnr: 49.5179 - val_ssim: 0.9956 - learning_rate: 0.0010
# Epoch 81/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.1432e-05 - psnr: 49.4330 - ssim: 0.9956 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.1553e-05 - val_psnr: 49.3785 - val_ssim: 0.9952 - learning_rate: 0.0010
# Epoch 82/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0926e-05 - psnr: 49.6486 - ssim: 0.9955 - val_loss: 0.0024 - val_mae: 0.0024 - val_mse: 1.6429e-05 - val_psnr: 47.8482 - val_ssim: 0.9935 - learning_rate: 0.0010
# Epoch 83/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0022 - mae: 0.0022 - mse: 1.4491e-05 - psnr: 48.5408 - ssim: 0.9946 - val_loss: 0.0018 - val_mae: 0.0018 - val_mse: 1.0656e-05 - val_psnr: 49.7309 - val_ssim: 0.9956 - learning_rate: 0.0010
# Epoch 84/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0021 - mae: 0.0021 - mse: 1.1899e-05 - psnr: 49.2651 - ssim: 0.9954 - val_loss: 0.0022 - val_mae: 0.0022 - val_mse: 1.2602e-05 - val_psnr: 49.0023 - val_ssim: 0.9953 - learning_rate: 0.0010
# Epoch 85/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0967e-05 - psnr: 49.6157 - ssim: 0.9955 - val_loss: 0.0018 - val_mae: 0.0018 - val_mse: 1.0471e-05 - val_psnr: 49.8072 - val_ssim: 0.9956 - learning_rate: 0.0010
# Epoch 86/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.1531e-05 - psnr: 49.4137 - ssim: 0.9955 - val_loss: 0.0024 - val_mae: 0.0024 - val_mse: 1.3356e-05 - val_psnr: 48.7498 - val_ssim: 0.9956 - learning_rate: 0.0010
# Epoch 87/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.1603e-05 - psnr: 49.3779 - ssim: 0.9955 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.1213e-05 - val_psnr: 49.5086 - val_ssim: 0.9955 - learning_rate: 0.0010
# Epoch 88/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.1518e-05 - psnr: 49.4035 - ssim: 0.9955 - val_loss: 0.0019 - val_mae: 0.0019 - val_mse: 1.0593e-05 - val_psnr: 49.7564 - val_ssim: 0.9956 - learning_rate: 0.0010
# Epoch 89/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0018 - mae: 0.0018 - mse: 1.0682e-05 - psnr: 49.7603 - ssim: 0.9956 - val_loss: 0.0017 - val_mae: 0.0017 - val_mse: 1.0163e-05 - val_psnr: 49.9374 - val_ssim: 0.9957 - learning_rate: 0.0010
# Epoch 90/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0021 - mae: 0.0021 - mse: 1.1692e-05 - psnr: 49.3431 - ssim: 0.9955 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.1177e-05 - val_psnr: 49.5229 - val_ssim: 0.9954 - learning_rate: 0.0010
# Epoch 91/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.1409e-05 - psnr: 49.4496 - ssim: 0.9956 - val_loss: 0.0018 - val_mae: 0.0018 - val_mse: 1.0374e-05 - val_psnr: 49.8478 - val_ssim: 0.9956 - learning_rate: 0.0010
# Epoch 92/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0911e-05 - psnr: 49.6418 - ssim: 0.9956 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.1371e-05 - val_psnr: 49.4497 - val_ssim: 0.9957 - learning_rate: 0.0010
# Epoch 93/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.1183e-05 - psnr: 49.5349 - ssim: 0.9957 - val_loss: 0.0018 - val_mae: 0.0018 - val_mse: 1.0256e-05 - val_psnr: 49.8974 - val_ssim: 0.9957 - learning_rate: 0.0010
# Epoch 94/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0021 - mae: 0.0021 - mse: 1.1840e-05 - psnr: 49.2868 - ssim: 0.9955 - val_loss: 0.0018 - val_mae: 0.0018 - val_mse: 1.0333e-05 - val_psnr: 49.8651 - val_ssim: 0.9956 - learning_rate: 0.0010
# Epoch 95/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0848e-05 - psnr: 49.6662 - ssim: 0.9957 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.1039e-05 - val_psnr: 49.5760 - val_ssim: 0.9957 - learning_rate: 0.0010
# Epoch 96/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.1351e-05 - psnr: 49.4679 - ssim: 0.9955 - val_loss: 0.0021 - val_mae: 0.0021 - val_mse: 1.1768e-05 - val_psnr: 49.3002 - val_ssim: 0.9957 - learning_rate: 0.0010
# Epoch 97/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.1781e-05 - psnr: 49.3703 - ssim: 0.9953 - val_loss: 0.0024 - val_mae: 0.0024 - val_mse: 1.2491e-05 - val_psnr: 49.0398 - val_ssim: 0.9954 - learning_rate: 0.0010
# Epoch 98/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.1283e-05 - psnr: 49.4957 - ssim: 0.9956 - val_loss: 0.0018 - val_mae: 0.0018 - val_mse: 1.0350e-05 - val_psnr: 49.8587 - val_ssim: 0.9957 - learning_rate: 0.0010
# Epoch 99/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.0944e-05 - psnr: 49.6233 - ssim: 0.9956 - val_loss: 0.0016 - val_mae: 0.0016 - val_mse: 9.7502e-06 - val_psnr: 50.1178 - val_ssim: 0.9957 - learning_rate: 0.0010
# Epoch 100/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0837e-05 - psnr: 49.6709 - ssim: 0.9957 - val_loss: 0.0025 - val_mae: 0.0025 - val_mse: 1.3561e-05 - val_psnr: 48.6831 - val_ssim: 0.9957 - learning_rate: 0.0010
# Epoch 101/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.1375e-05 - psnr: 49.5069 - ssim: 0.9955 - val_loss: 0.0019 - val_mae: 0.0019 - val_mse: 1.0370e-05 - val_psnr: 49.8486 - val_ssim: 0.9957 - learning_rate: 0.0010
# Epoch 102/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0494e-05 - psnr: 49.8125 - ssim: 0.9957 - val_loss: 0.0021 - val_mae: 0.0021 - val_mse: 1.1463e-05 - val_psnr: 49.4156 - val_ssim: 0.9958 - learning_rate: 0.0010
# Epoch 103/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.1378e-05 - psnr: 49.4972 - ssim: 0.9956 - val_loss: 0.0015 - val_mae: 0.0015 - val_mse: 9.6810e-06 - val_psnr: 50.1492 - val_ssim: 0.9957 - learning_rate: 0.0010
# Epoch 104/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.1034e-05 - psnr: 49.5910 - ssim: 0.9956 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.0877e-05 - val_psnr: 49.6410 - val_ssim: 0.9956 - learning_rate: 0.0010
# Epoch 105/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0650e-05 - psnr: 49.7462 - ssim: 0.9957 - val_loss: 0.0021 - val_mae: 0.0021 - val_mse: 1.1384e-05 - val_psnr: 49.4440 - val_ssim: 0.9955 - learning_rate: 0.0010
# Epoch 106/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0781e-05 - psnr: 49.6913 - ssim: 0.9957 - val_loss: 0.0021 - val_mae: 0.0021 - val_mse: 1.2285e-05 - val_psnr: 49.1160 - val_ssim: 0.9958 - learning_rate: 0.0010
# Epoch 107/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0786e-05 - psnr: 49.6896 - ssim: 0.9957 - val_loss: 0.0018 - val_mae: 0.0018 - val_mse: 1.0295e-05 - val_psnr: 49.8809 - val_ssim: 0.9958 - learning_rate: 0.0010
# Epoch 108/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0725e-05 - psnr: 49.7125 - ssim: 0.9957 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.1357e-05 - val_psnr: 49.4528 - val_ssim: 0.9956 - learning_rate: 0.0010
# Epoch 109/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0901e-05 - psnr: 49.6469 - ssim: 0.9957 - val_loss: 0.0018 - val_mae: 0.0018 - val_mse: 1.0652e-05 - val_psnr: 49.7332 - val_ssim: 0.9955 - learning_rate: 0.0010
# Epoch 110/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0623e-05 - psnr: 49.7578 - ssim: 0.9957 - val_loss: 0.0019 - val_mae: 0.0019 - val_mse: 1.0722e-05 - val_psnr: 49.7065 - val_ssim: 0.9958 - learning_rate: 0.0010
# Epoch 111/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0018 - mae: 0.0018 - mse: 1.0169e-05 - psnr: 49.9444 - ssim: 0.9958 - val_loss: 0.0022 - val_mae: 0.0022 - val_mse: 1.3285e-05 - val_psnr: 48.7775 - val_ssim: 0.9956 - learning_rate: 0.0010
# Epoch 112/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.1746e-05 - psnr: 49.3620 - ssim: 0.9955 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.0862e-05 - val_psnr: 49.6472 - val_ssim: 0.9958 - learning_rate: 0.0010
# Epoch 113/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.0982e-05 - psnr: 49.6113 - ssim: 0.9957 - val_loss: 0.0019 - val_mae: 0.0019 - val_mse: 1.0749e-05 - val_psnr: 49.6943 - val_ssim: 0.9957 - learning_rate: 0.0010
# Epoch 114/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0018 - mae: 0.0018 - mse: 1.0544e-05 - psnr: 49.7864 - ssim: 0.9958 - val_loss: 0.0018 - val_mae: 0.0018 - val_mse: 1.0538e-05 - val_psnr: 49.7788 - val_ssim: 0.9958 - learning_rate: 0.0010
# Epoch 115/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.0814e-05 - psnr: 49.6730 - ssim: 0.9957 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.0850e-05 - val_psnr: 49.6533 - val_ssim: 0.9956 - learning_rate: 0.0010
# Epoch 116/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0591e-05 - psnr: 49.7635 - ssim: 0.9957 - val_loss: 0.0017 - val_mae: 0.0017 - val_mse: 9.9007e-06 - val_psnr: 50.0507 - val_ssim: 0.9958 - learning_rate: 0.0010
# Epoch 117/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0644e-05 - psnr: 49.7465 - ssim: 0.9958 - val_loss: 0.0017 - val_mae: 0.0017 - val_mse: 9.6155e-06 - val_psnr: 50.1778 - val_ssim: 0.9959 - learning_rate: 0.0010
# Epoch 118/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0018 - mae: 0.0018 - mse: 1.0298e-05 - psnr: 49.8909 - ssim: 0.9958 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.0672e-05 - val_psnr: 49.7235 - val_ssim: 0.9959 - learning_rate: 0.0010
# Epoch 119/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0326e-05 - psnr: 49.8796 - ssim: 0.9958 - val_loss: 0.0021 - val_mae: 0.0021 - val_mse: 1.1331e-05 - val_psnr: 49.4658 - val_ssim: 0.9959 - learning_rate: 0.0010
# Epoch 120/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.1258e-05 - psnr: 49.5761 - ssim: 0.9955 - val_loss: 0.0021 - val_mae: 0.0021 - val_mse: 1.2423e-05 - val_psnr: 49.0644 - val_ssim: 0.9956 - learning_rate: 0.0010
# Epoch 121/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.1095e-05 - psnr: 49.5881 - ssim: 0.9956 - val_loss: 0.0017 - val_mae: 0.0017 - val_mse: 9.7958e-06 - val_psnr: 50.0960 - val_ssim: 0.9959 - learning_rate: 0.0010
# Epoch 122/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0716e-05 - psnr: 49.7162 - ssim: 0.9958 - val_loss: 0.0016 - val_mae: 0.0016 - val_mse: 9.3019e-06 - val_psnr: 50.3224 - val_ssim: 0.9959 - learning_rate: 0.0010
# Epoch 123/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0522e-05 - psnr: 49.8118 - ssim: 0.9957 - val_loss: 0.0024 - val_mae: 0.0024 - val_mse: 1.3083e-05 - val_psnr: 48.8395 - val_ssim: 0.9953 - learning_rate: 0.0010
# Epoch 124/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.0994e-05 - psnr: 49.6061 - ssim: 0.9957 - val_loss: 0.0019 - val_mae: 0.0019 - val_mse: 1.0457e-05 - val_psnr: 49.8128 - val_ssim: 0.9957 - learning_rate: 0.0010
# Epoch 125/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0466e-05 - psnr: 49.8192 - ssim: 0.9958 - val_loss: 0.0019 - val_mae: 0.0019 - val_mse: 1.0651e-05 - val_psnr: 49.7351 - val_ssim: 0.9959 - learning_rate: 0.0010
# Epoch 126/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0017 - mae: 0.0017 - mse: 9.8393e-06 - psnr: 50.0906 - ssim: 0.9959 - val_loss: 0.0017 - val_mae: 0.0017 - val_mse: 9.8117e-06 - val_psnr: 50.0904 - val_ssim: 0.9957 - learning_rate: 0.0010
# Epoch 127/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0018 - mae: 0.0018 - mse: 1.0456e-05 - psnr: 49.8337 - ssim: 0.9958 - val_loss: 0.0018 - val_mae: 0.0018 - val_mse: 9.8332e-06 - val_psnr: 50.0821 - val_ssim: 0.9960 - learning_rate: 0.0010
# Epoch 128/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0018 - mae: 0.0018 - mse: 1.0405e-05 - psnr: 49.8567 - ssim: 0.9958 - val_loss: 0.0017 - val_mae: 0.0017 - val_mse: 1.0257e-05 - val_psnr: 49.8976 - val_ssim: 0.9957 - learning_rate: 0.0010
# Epoch 129/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0649e-05 - psnr: 49.7481 - ssim: 0.9958 - val_loss: 0.0017 - val_mae: 0.0017 - val_mse: 9.7242e-06 - val_psnr: 50.1294 - val_ssim: 0.9959 - learning_rate: 0.0010
# Epoch 130/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0609e-05 - psnr: 49.7965 - ssim: 0.9957 - val_loss: 0.0022 - val_mae: 0.0022 - val_mse: 1.1553e-05 - val_psnr: 49.3791 - val_ssim: 0.9956 - learning_rate: 0.0010
# Epoch 131/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0533e-05 - psnr: 49.7970 - ssim: 0.9958 - val_loss: 0.0019 - val_mae: 0.0019 - val_mse: 1.0264e-05 - val_psnr: 49.8939 - val_ssim: 0.9957 - learning_rate: 0.0010
# Epoch 132/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0018 - mae: 0.0018 - mse: 1.0091e-05 - psnr: 49.9840 - ssim: 0.9959 - val_loss: 0.0018 - val_mae: 0.0018 - val_mse: 1.0303e-05 - val_psnr: 49.8772 - val_ssim: 0.9957 - learning_rate: 0.0010
# Epoch 133/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0018 - mae: 0.0018 - mse: 1.0234e-05 - psnr: 49.9221 - ssim: 0.9958 - val_loss: 0.0018 - val_mae: 0.0018 - val_mse: 1.0183e-05 - val_psnr: 49.9305 - val_ssim: 0.9959 - learning_rate: 0.0010
# Epoch 134/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0017 - mae: 0.0017 - mse: 9.7859e-06 - psnr: 50.1170 - ssim: 0.9959 - val_loss: 0.0019 - val_mae: 0.0019 - val_mse: 1.0373e-05 - val_psnr: 49.8485 - val_ssim: 0.9959 - learning_rate: 0.0010
# Epoch 135/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.0684e-05 - psnr: 49.7258 - ssim: 0.9958 - val_loss: 0.0018 - val_mae: 0.0018 - val_mse: 9.9630e-06 - val_psnr: 50.0242 - val_ssim: 0.9959 - learning_rate: 0.0010
# Epoch 136/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0018 - mae: 0.0018 - mse: 1.0150e-05 - psnr: 49.9526 - ssim: 0.9959 - val_loss: 0.0022 - val_mae: 0.0022 - val_mse: 1.2535e-05 - val_psnr: 49.0291 - val_ssim: 0.9958 - learning_rate: 0.0010
# Epoch 137/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0030 - mae: 0.0030 - mse: 4.3733e-05 - psnr: 47.1387 - ssim: 0.9922 - val_loss: 0.0024 - val_mae: 0.0024 - val_mse: 1.6504e-05 - val_psnr: 47.8302 - val_ssim: 0.9941 - learning_rate: 0.0010
# Epoch 138/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0021 - mae: 0.0021 - mse: 1.4242e-05 - psnr: 48.4791 - ssim: 0.9944 - val_loss: 0.0022 - val_mae: 0.0022 - val_mse: 1.2855e-05 - val_psnr: 48.9156 - val_ssim: 0.9950 - learning_rate: 0.0010
# Epoch 139/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0022 - mae: 0.0022 - mse: 1.3568e-05 - psnr: 48.7602 - ssim: 0.9949 - val_loss: 0.0021 - val_mae: 0.0021 - val_mse: 1.1736e-05 - val_psnr: 49.3109 - val_ssim: 0.9955 - learning_rate: 0.0010
# Epoch 140/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.1249e-05 - psnr: 49.5032 - ssim: 0.9955 - val_loss: 0.0019 - val_mae: 0.0019 - val_mse: 1.0856e-05 - val_psnr: 49.6520 - val_ssim: 0.9957 - learning_rate: 0.0010
# Epoch 141/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0017 - mae: 0.0017 - mse: 9.9558e-06 - psnr: 50.0367 - ssim: 0.9958 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.1108e-05 - val_psnr: 49.5507 - val_ssim: 0.9955 - learning_rate: 0.0010
# Epoch 142/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.0965e-05 - psnr: 49.6159 - ssim: 0.9956 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.0809e-05 - val_psnr: 49.6703 - val_ssim: 0.9959 - learning_rate: 0.0010
# Epoch 143/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0018 - mae: 0.0018 - mse: 1.0316e-05 - psnr: 49.9073 - ssim: 0.9958 - val_loss: 0.0019 - val_mae: 0.0019 - val_mse: 1.0265e-05 - val_psnr: 49.8928 - val_ssim: 0.9958 - learning_rate: 0.0010
# Epoch 144/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0018 - mae: 0.0018 - mse: 1.0335e-05 - psnr: 49.8703 - ssim: 0.9958 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.1044e-05 - val_psnr: 49.5752 - val_ssim: 0.9958 - learning_rate: 0.0010
# Epoch 145/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0618e-05 - psnr: 49.7594 - ssim: 0.9958 - val_loss: 0.0018 - val_mae: 0.0018 - val_mse: 1.0135e-05 - val_psnr: 49.9487 - val_ssim: 0.9958 - learning_rate: 0.0010
# Epoch 146/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0443e-05 - psnr: 49.8298 - ssim: 0.9958 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.0777e-05 - val_psnr: 49.6830 - val_ssim: 0.9958 - learning_rate: 0.0010
# Epoch 147/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0018 - mae: 0.0018 - mse: 1.0304e-05 - psnr: 49.8973 - ssim: 0.9958 - val_loss: 0.0019 - val_mae: 0.0019 - val_mse: 1.0464e-05 - val_psnr: 49.8109 - val_ssim: 0.9959 - learning_rate: 0.0010
# Epoch 148/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0018 - mae: 0.0018 - mse: 1.0002e-05 - psnr: 50.0168 - ssim: 0.9959 - val_loss: 0.0016 - val_mae: 0.0016 - val_mse: 9.1833e-06 - val_psnr: 50.3785 - val_ssim: 0.9960 - learning_rate: 0.0010
# Epoch 149/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0016 - mae: 0.0016 - mse: 9.0347e-06 - psnr: 50.4486 - ssim: 0.9960 - val_loss: 0.0015 - val_mae: 0.0015 - val_mse: 8.8786e-06 - val_psnr: 50.5257 - val_ssim: 0.9960 - learning_rate: 0.0010
# Epoch 150/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0021 - mae: 0.0021 - mse: 1.3075e-05 - psnr: 49.1235 - ssim: 0.9952 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.0849e-05 - val_psnr: 49.6548 - val_ssim: 0.9959 - learning_rate: 0.0010
# Epoch 151/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0347e-05 - psnr: 49.8667 - ssim: 0.9959 - val_loss: 0.0018 - val_mae: 0.0018 - val_mse: 1.0269e-05 - val_psnr: 49.8933 - val_ssim: 0.9959 - learning_rate: 0.0010
# Epoch 152/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0017 - mae: 0.0017 - mse: 9.8084e-06 - psnr: 50.1056 - ssim: 0.9959 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.0737e-05 - val_psnr: 49.6988 - val_ssim: 0.9958 - learning_rate: 0.0010
# Epoch 153/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.0602e-05 - psnr: 49.7639 - ssim: 0.9958 - val_loss: 0.0019 - val_mae: 0.0019 - val_mse: 1.0248e-05 - val_psnr: 49.8995 - val_ssim: 0.9960 - learning_rate: 0.0010
# Epoch 154/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0186e-05 - psnr: 49.9350 - ssim: 0.9959 - val_loss: 0.0018 - val_mae: 0.0018 - val_mse: 9.5647e-06 - val_psnr: 50.2013 - val_ssim: 0.9959 - learning_rate: 0.0010
# Epoch 155/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0017 - mae: 0.0017 - mse: 9.6141e-06 - psnr: 50.1920 - ssim: 0.9960 - val_loss: 0.0019 - val_mae: 0.0019 - val_mse: 1.0711e-05 - val_psnr: 49.7115 - val_ssim: 0.9960 - learning_rate: 0.0010
# Epoch 156/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0683e-05 - psnr: 49.7712 - ssim: 0.9958 - val_loss: 0.0018 - val_mae: 0.0018 - val_mse: 1.0009e-05 - val_psnr: 50.0032 - val_ssim: 0.9958 - learning_rate: 0.0010
# Epoch 157/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0018 - mae: 0.0018 - mse: 1.0044e-05 - psnr: 49.9997 - ssim: 0.9959 - val_loss: 0.0015 - val_mae: 0.0015 - val_mse: 8.7624e-06 - val_psnr: 50.5830 - val_ssim: 0.9961 - learning_rate: 0.0010
# Epoch 158/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0016 - mae: 0.0016 - mse: 9.2016e-06 - psnr: 50.3832 - ssim: 0.9960 - val_loss: 0.0024 - val_mae: 0.0024 - val_mse: 1.2902e-05 - val_psnr: 48.9009 - val_ssim: 0.9959 - learning_rate: 0.0010
# Epoch 159/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.0799e-05 - psnr: 49.6904 - ssim: 0.9959 - val_loss: 0.0016 - val_mae: 0.0016 - val_mse: 9.2947e-06 - val_psnr: 50.3258 - val_ssim: 0.9960 - learning_rate: 0.0010
# Epoch 160/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.0560e-05 - psnr: 49.7813 - ssim: 0.9958 - val_loss: 0.0017 - val_mae: 0.0017 - val_mse: 9.3339e-06 - val_psnr: 50.3080 - val_ssim: 0.9961 - learning_rate: 0.0010
# Epoch 161/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0358e-05 - psnr: 49.8664 - ssim: 0.9959 - val_loss: 0.0019 - val_mae: 0.0019 - val_mse: 1.0149e-05 - val_psnr: 49.9418 - val_ssim: 0.9959 - learning_rate: 0.0010
# Epoch 162/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0018 - mae: 0.0018 - mse: 9.8607e-06 - psnr: 50.0782 - ssim: 0.9959 - val_loss: 0.0016 - val_mae: 0.0016 - val_mse: 8.9598e-06 - val_psnr: 50.4865 - val_ssim: 0.9961 - learning_rate: 0.0010
# Epoch 163/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0017 - mae: 0.0017 - mse: 9.8049e-06 - psnr: 50.1064 - ssim: 0.9960 - val_loss: 0.0015 - val_mae: 0.0015 - val_mse: 8.6305e-06 - val_psnr: 50.6492 - val_ssim: 0.9961 - learning_rate: 0.0010
# Epoch 164/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0016 - mae: 0.0016 - mse: 9.3370e-06 - psnr: 50.3199 - ssim: 0.9960 - val_loss: 0.0015 - val_mae: 0.0015 - val_mse: 8.6990e-06 - val_psnr: 50.6150 - val_ssim: 0.9961 - learning_rate: 0.0010
# Epoch 165/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0015 - mae: 0.0015 - mse: 8.8492e-06 - psnr: 50.5406 - ssim: 0.9961 - val_loss: 0.0017 - val_mae: 0.0017 - val_mse: 9.3090e-06 - val_psnr: 50.3206 - val_ssim: 0.9961 - learning_rate: 0.0010
# Epoch 166/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0018 - mae: 0.0018 - mse: 1.1665e-05 - psnr: 49.6274 - ssim: 0.9954 - val_loss: 0.0023 - val_mae: 0.0023 - val_mse: 1.3448e-05 - val_psnr: 48.7229 - val_ssim: 0.9956 - learning_rate: 0.0010
# Epoch 167/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0017 - mae: 0.0017 - mse: 9.8410e-06 - psnr: 50.0990 - ssim: 0.9959 - val_loss: 0.0017 - val_mae: 0.0017 - val_mse: 9.2915e-06 - val_psnr: 50.3281 - val_ssim: 0.9961 - learning_rate: 0.0010
# Epoch 168/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0349e-05 - psnr: 49.8699 - ssim: 0.9959 - val_loss: 0.0016 - val_mae: 0.0016 - val_mse: 9.1699e-06 - val_psnr: 50.3841 - val_ssim: 0.9961 - learning_rate: 0.0010
# Epoch 169/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0018 - mae: 0.0018 - mse: 9.9231e-06 - psnr: 50.0543 - ssim: 0.9960 - val_loss: 0.0015 - val_mae: 0.0015 - val_mse: 8.7299e-06 - val_psnr: 50.5993 - val_ssim: 0.9961 - learning_rate: 0.0010
# Epoch 170/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0018 - mae: 0.0018 - mse: 9.9447e-06 - psnr: 50.0591 - ssim: 0.9959 - val_loss: 0.0021 - val_mae: 0.0021 - val_mse: 1.1424e-05 - val_psnr: 49.4312 - val_ssim: 0.9960 - learning_rate: 0.0010
# Epoch 171/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0740e-05 - psnr: 49.7752 - ssim: 0.9957 - val_loss: 0.0018 - val_mae: 0.0018 - val_mse: 1.0224e-05 - val_psnr: 49.9109 - val_ssim: 0.9956 - learning_rate: 0.0010
# Epoch 172/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0018 - mae: 0.0018 - mse: 1.0206e-05 - psnr: 49.9270 - ssim: 0.9959 - val_loss: 0.0017 - val_mae: 0.0017 - val_mse: 9.2683e-06 - val_psnr: 50.3379 - val_ssim: 0.9960 - learning_rate: 0.0010
# Epoch 173/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0018 - mae: 0.0018 - mse: 9.7015e-06 - psnr: 50.1476 - ssim: 0.9960 - val_loss: 0.0021 - val_mae: 0.0021 - val_mse: 1.1097e-05 - val_psnr: 49.5557 - val_ssim: 0.9958 - learning_rate: 0.0010
# Epoch 174/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0018 - mae: 0.0018 - mse: 9.9206e-06 - psnr: 50.0517 - ssim: 0.9960 - val_loss: 0.0025 - val_mae: 0.0025 - val_mse: 1.5786e-05 - val_psnr: 48.0317 - val_ssim: 0.9956 - learning_rate: 0.0010
# Epoch 175/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0017 - mae: 0.0017 - mse: 9.8090e-06 - psnr: 50.1365 - ssim: 0.9960 - val_loss: 0.0022 - val_mae: 0.0022 - val_mse: 1.1926e-05 - val_psnr: 49.2403 - val_ssim: 0.9954 - learning_rate: 0.0010
# Epoch 176/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0477e-05 - psnr: 49.8154 - ssim: 0.9958 - val_loss: 0.0017 - val_mae: 0.0017 - val_mse: 9.1804e-06 - val_psnr: 50.3791 - val_ssim: 0.9961 - learning_rate: 0.0010
# Epoch 177/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0018 - mae: 0.0018 - mse: 9.8969e-06 - psnr: 50.0618 - ssim: 0.9960 - val_loss: 0.0017 - val_mae: 0.0017 - val_mse: 9.5082e-06 - val_psnr: 50.2276 - val_ssim: 0.9960 - learning_rate: 0.0010
# Epoch 178/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0017 - mae: 0.0017 - mse: 9.6401e-06 - psnr: 50.1805 - ssim: 0.9960 - val_loss: 0.0021 - val_mae: 0.0021 - val_mse: 1.0579e-05 - val_psnr: 49.7627 - val_ssim: 0.9958 - learning_rate: 0.0010
# Epoch 179/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0018 - mae: 0.0018 - mse: 9.7459e-06 - psnr: 50.1261 - ssim: 0.9960 - val_loss: 0.0019 - val_mae: 0.0019 - val_mse: 1.0287e-05 - val_psnr: 49.8872 - val_ssim: 0.9961 - learning_rate: 0.0010
# Epoch 180/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0415e-05 - psnr: 49.8771 - ssim: 0.9958 - val_loss: 0.0022 - val_mae: 0.0022 - val_mse: 1.2342e-05 - val_psnr: 49.0964 - val_ssim: 0.9959 - learning_rate: 0.0010
# Epoch 181/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0123e-05 - psnr: 49.9641 - ssim: 0.9959 - val_loss: 0.0019 - val_mae: 0.0019 - val_mse: 1.0381e-05 - val_psnr: 49.8475 - val_ssim: 0.9961 - learning_rate: 0.0010
# Epoch 182/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0161e-05 - psnr: 49.9428 - ssim: 0.9960 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.0438e-05 - val_psnr: 49.8199 - val_ssim: 0.9958 - learning_rate: 0.0010
# Epoch 183/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0018 - mae: 0.0018 - mse: 9.6581e-06 - psnr: 50.1676 - ssim: 0.9960 - val_loss: 0.0015 - val_mae: 0.0015 - val_mse: 8.9733e-06 - val_psnr: 50.4790 - val_ssim: 0.9960 - learning_rate: 0.0010
# Epoch 184/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0018 - mae: 0.0018 - mse: 1.0161e-05 - psnr: 49.9899 - ssim: 0.9959 - val_loss: 0.0015 - val_mae: 0.0015 - val_mse: 9.0328e-06 - val_psnr: 50.4508 - val_ssim: 0.9960 - learning_rate: 0.0010
# Epoch 185/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0017 - mae: 0.0017 - mse: 9.5235e-06 - psnr: 50.2386 - ssim: 0.9960 - val_loss: 0.0015 - val_mae: 0.0015 - val_mse: 8.7326e-06 - val_psnr: 50.5973 - val_ssim: 0.9961 - learning_rate: 0.0010
# Epoch 186/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0016 - mae: 0.0016 - mse: 9.2045e-06 - psnr: 50.3912 - ssim: 0.9961 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.1023e-05 - val_psnr: 49.5845 - val_ssim: 0.9957 - learning_rate: 0.0010
# Epoch 187/250
# ...
# Epoch 190/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.1637e-05 - psnr: 49.3833 - ssim: 0.9955 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.0561e-05 - val_psnr: 49.7688 - val_ssim: 0.9958 - learning_rate: 0.0010
# Epoch 191/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0155e-05 - psnr: 49.9504 - ssim: 0.9959 - val_loss: 0.0016 - val_mae: 0.0016 - val_mse: 9.0604e-06 - val_psnr: 50.4374 - val_ssim: 0.9960 - learning_rate: 0.0010
# Epoch 192/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.1195e-05 - psnr: 49.8463 - ssim: 0.9959 - val_loss: 0.0016 - val_mae: 0.0016 - val_mse: 8.9441e-06 - val_psnr: 50.4939 - val_ssim: 0.9961 - learning_rate: 0.0010
# Epoch 193/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0018 - mae: 0.0018 - mse: 9.9609e-06 - psnr: 50.0481 - ssim: 0.9960 - val_loss: 0.0021 - val_mae: 0.0021 - val_mse: 1.0808e-05 - val_psnr: 49.6709 - val_ssim: 0.9959 - learning_rate: 0.0010
# Epoch 194/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0114e-05 - psnr: 49.9690 - ssim: 0.9960 - val_loss: 0.0016 - val_mae: 0.0016 - val_mse: 9.0163e-06 - val_psnr: 50.4586 - val_ssim: 0.9961 - learning_rate: 0.0010
# Epoch 195/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0018 - mae: 0.0018 - mse: 9.6502e-06 - psnr: 50.1741 - ssim: 0.9960 - val_loss: 0.0021 - val_mae: 0.0021 - val_mse: 1.1734e-05 - val_psnr: 49.3170 - val_ssim: 0.9960 - learning_rate: 0.0010
# Epoch 196/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0273e-05 - psnr: 49.9055 - ssim: 0.9959 - val_loss: 0.0021 - val_mae: 0.0021 - val_mse: 1.0737e-05 - val_psnr: 49.6989 - val_ssim: 0.9959 - learning_rate: 0.0010
# Epoch 197/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0019 - mae: 0.0019 - mse: 9.9117e-06 - psnr: 50.0502 - ssim: 0.9960 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.0818e-05 - val_psnr: 49.6676 - val_ssim: 0.9960 - learning_rate: 0.0010
# Epoch 198/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0018 - mae: 0.0018 - mse: 9.9337e-06 - psnr: 50.0443 - ssim: 0.9960 - val_loss: 0.0018 - val_mae: 0.0018 - val_mse: 9.9159e-06 - val_psnr: 50.0461 - val_ssim: 0.9961 - learning_rate: 0.0010
# Epoch 199/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0018 - mae: 0.0018 - mse: 9.8061e-06 - psnr: 50.1058 - ssim: 0.9960 - val_loss: 0.0017 - val_mae: 0.0017 - val_mse: 9.2757e-06 - val_psnr: 50.3344 - val_ssim: 0.9961 - learning_rate: 0.0010
# Epoch 200/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0018 - mae: 0.0018 - mse: 9.8806e-06 - psnr: 50.0681 - ssim: 0.9960 - val_loss: 0.0016 - val_mae: 0.0016 - val_mse: 8.9478e-06 - val_psnr: 50.4924 - val_ssim: 0.9961 - learning_rate: 0.0010
# Epoch 201/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0016 - mae: 0.0016 - mse: 9.0005e-06 - psnr: 50.4760 - ssim: 0.9961 - val_loss: 0.0016 - val_mae: 0.0016 - val_mse: 8.7566e-06 - val_psnr: 50.5857 - val_ssim: 0.9961 - learning_rate: 0.0010
# Epoch 202/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0024 - mae: 0.0024 - mse: 1.7817e-05 - psnr: 48.2924 - ssim: 0.9940 - val_loss: 0.0019 - val_mae: 0.0019 - val_mse: 1.0853e-05 - val_psnr: 49.6517 - val_ssim: 0.9956 - learning_rate: 0.0010
# Epoch 203/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0018 - mae: 0.0018 - mse: 1.0350e-05 - psnr: 49.8689 - ssim: 0.9957 - val_loss: 0.0015 - val_mae: 0.0015 - val_mse: 9.0146e-06 - val_psnr: 50.4595 - val_ssim: 0.9960 - learning_rate: 0.0010
# Epoch 204/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0018 - mae: 0.0018 - mse: 9.9863e-06 - psnr: 50.0249 - ssim: 0.9959 - val_loss: 0.0018 - val_mae: 0.0018 - val_mse: 9.7529e-06 - val_psnr: 50.1161 - val_ssim: 0.9960 - learning_rate: 0.0010
# Epoch 205/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0018 - mae: 0.0018 - mse: 9.9723e-06 - psnr: 50.0308 - ssim: 0.9960 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.5164e-06 - val_psnr: 50.7070 - val_ssim: 0.9962 - learning_rate: 0.0010
# Epoch 206/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0015 - mae: 0.0015 - mse: 8.6409e-06 - psnr: 50.6437 - ssim: 0.9961 - val_loss: 0.0015 - val_mae: 0.0015 - val_mse: 8.6648e-06 - val_psnr: 50.6317 - val_ssim: 0.9961 - learning_rate: 0.0010
# Epoch 207/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0023 - mae: 0.0023 - mse: 1.5507e-05 - psnr: 48.6269 - ssim: 0.9946 - val_loss: 0.0016 - val_mae: 0.0016 - val_mse: 9.1972e-06 - val_psnr: 50.3722 - val_ssim: 0.9960 - learning_rate: 0.0010
# Epoch 208/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0017 - mae: 0.0017 - mse: 9.8027e-06 - psnr: 50.1100 - ssim: 0.9959 - val_loss: 0.0015 - val_mae: 0.0015 - val_mse: 9.1091e-06 - val_psnr: 50.4141 - val_ssim: 0.9960 - learning_rate: 0.0010
# Epoch 209/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0018 - mae: 0.0018 - mse: 9.8840e-06 - psnr: 50.0680 - ssim: 0.9960 - val_loss: 0.0015 - val_mae: 0.0015 - val_mse: 8.7623e-06 - val_psnr: 50.5833 - val_ssim: 0.9961 - learning_rate: 0.0010
# Epoch 210/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0016 - mae: 0.0016 - mse: 9.2031e-06 - psnr: 50.3793 - ssim: 0.9961 - val_loss: 0.0019 - val_mae: 0.0019 - val_mse: 1.0452e-05 - val_psnr: 49.8149 - val_ssim: 0.9959 - learning_rate: 0.0010
# Epoch 211/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0019 - mae: 0.0019 - mse: 1.0028e-05 - psnr: 50.0036 - ssim: 0.9960 - val_loss: 0.0018 - val_mae: 0.0018 - val_mse: 9.4019e-06 - val_psnr: 50.2758 - val_ssim: 0.9960 - learning_rate: 0.0010
# Epoch 212/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0018 - mae: 0.0018 - mse: 9.7841e-06 - psnr: 50.1101 - ssim: 0.9960 - val_loss: 0.0018 - val_mae: 0.0018 - val_mse: 9.9017e-06 - val_psnr: 50.0529 - val_ssim: 0.9961 - learning_rate: 0.0010
# Epoch 213/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0019 - mae: 0.0019 - mse: 9.8581e-06 - psnr: 50.0742 - ssim: 0.9960 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.5778e-06 - val_psnr: 50.6755 - val_ssim: 0.9961 - learning_rate: 0.0010
# Epoch 214/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0017 - mae: 0.0017 - mse: 9.4808e-06 - psnr: 50.2555 - ssim: 0.9961 - val_loss: 0.0016 - val_mae: 0.0016 - val_mse: 8.8880e-06 - val_psnr: 50.5205 - val_ssim: 0.9961 - learning_rate: 0.0010
# Epoch 215/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0019 - mae: 0.0019 - mse: 9.9010e-06 - psnr: 50.0591 - ssim: 0.9960 - val_loss: 0.0017 - val_mae: 0.0017 - val_mse: 9.2634e-06 - val_psnr: 50.3398 - val_ssim: 0.9961 - learning_rate: 0.0010
# Epoch 216/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0018 - mae: 0.0018 - mse: 9.6208e-06 - psnr: 50.1889 - ssim: 0.9960 - val_loss: 0.0019 - val_mae: 0.0019 - val_mse: 1.0318e-05 - val_psnr: 49.8736 - val_ssim: 0.9961 - learning_rate: 0.0010
# Epoch 217/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0018 - mae: 0.0018 - mse: 9.6711e-06 - psnr: 50.1644 - ssim: 0.9960 - val_loss: 0.0017 - val_mae: 0.0017 - val_mse: 9.5380e-06 - val_psnr: 50.2140 - val_ssim: 0.9961 - learning_rate: 0.0010
# Epoch 218/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0018 - mae: 0.0018 - mse: 9.7695e-06 - psnr: 50.1187 - ssim: 0.9961 - val_loss: 0.0017 - val_mae: 0.0017 - val_mse: 9.4671e-06 - val_psnr: 50.2473 - val_ssim: 0.9960 - learning_rate: 0.0010
# Epoch 219/250
# 671/672 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.0017 - mae: 0.0017 - mse: 9.6467e-06 - psnr: 50.1731 - ssim: 0.9961
# Epoch 219: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0017 - mae: 0.0017 - mse: 9.6463e-06 - psnr: 50.1733 - ssim: 0.9961 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.4251e-06 - val_psnr: 50.7539 - val_ssim: 0.9962 - learning_rate: 0.0010
# Epoch 220/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3502e-06 - psnr: 50.7911 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.3217e-06 - val_psnr: 50.8077 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 221/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3574e-06 - psnr: 50.7881 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.3198e-06 - val_psnr: 50.8087 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 222/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3260e-06 - psnr: 50.8052 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.3114e-06 - val_psnr: 50.8131 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 223/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3207e-06 - psnr: 50.8076 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.3228e-06 - val_psnr: 50.8071 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 224/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3226e-06 - psnr: 50.8057 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.3043e-06 - val_psnr: 50.8168 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 225/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3326e-06 - psnr: 50.8008 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.3050e-06 - val_psnr: 50.8164 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 226/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3105e-06 - psnr: 50.8123 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.2961e-06 - val_psnr: 50.8211 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 227/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3223e-06 - psnr: 50.8078 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.2851e-06 - val_psnr: 50.8269 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 228/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3342e-06 - psnr: 50.8016 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.2712e-06 - val_psnr: 50.8343 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 229/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.2787e-06 - psnr: 50.8306 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.2969e-06 - val_psnr: 50.8208 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 230/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.2816e-06 - psnr: 50.8286 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.2674e-06 - val_psnr: 50.8362 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 231/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.2683e-06 - psnr: 50.8343 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.2509e-06 - val_psnr: 50.8449 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 232/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.2332e-06 - psnr: 50.8551 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.2459e-06 - val_psnr: 50.8475 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 233/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.2589e-06 - psnr: 50.8407 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.2605e-06 - val_psnr: 50.8398 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 234/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.2979e-06 - psnr: 50.8213 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.2560e-06 - val_psnr: 50.8422 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 235/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.2748e-06 - psnr: 50.8310 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.2410e-06 - val_psnr: 50.8501 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 236/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.3188e-06 - psnr: 50.8085 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.2385e-06 - val_psnr: 50.8515 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 237/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.2663e-06 - psnr: 50.8349 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.2559e-06 - val_psnr: 50.8423 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 238/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.2655e-06 - psnr: 50.8365 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.2841e-06 - val_psnr: 50.8275 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 239/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.2757e-06 - psnr: 50.8318 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.2479e-06 - val_psnr: 50.8465 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 240/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.2329e-06 - psnr: 50.8561 - ssim: 0.9963 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.2277e-06 - val_psnr: 50.8572 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 241/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.2290e-06 - psnr: 50.8565 - ssim: 0.9963 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.2387e-06 - val_psnr: 50.8513 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 242/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.2495e-06 - psnr: 50.8453 - ssim: 0.9963 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.2294e-06 - val_psnr: 50.8563 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 243/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.2406e-06 - psnr: 50.8487 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.2360e-06 - val_psnr: 50.8528 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 244/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.2538e-06 - psnr: 50.8427 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.2436e-06 - val_psnr: 50.8488 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 245/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.2664e-06 - psnr: 50.8369 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.2222e-06 - val_psnr: 50.8602 - val_ssim: 0.9963 - learning_rate: 1.0000e-04
# Epoch 246/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.2583e-06 - psnr: 50.8399 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.2223e-06 - val_psnr: 50.8601 - val_ssim: 0.9963 - learning_rate: 1.0000e-04
# Epoch 247/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.2466e-06 - psnr: 50.8462 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.2965e-06 - val_psnr: 50.8210 - val_ssim: 0.9962 - learning_rate: 1.0000e-04
# Epoch 248/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 121ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.2612e-06 - psnr: 50.8388 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.2156e-06 - val_psnr: 50.8636 - val_ssim: 0.9963 - learning_rate: 1.0000e-04
# Epoch 249/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 81s 120ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.2466e-06 - psnr: 50.8466 - ssim: 0.9962 - val_loss: 0.0014 - val_mae: 0.0014 - val_mse: 8.2161e-06 - val_psnr: 50.8633 - val_ssim: 0.9963 - learning_rate: 1.0000e-04
# Epoch 249: early stopping
# Training time: 20260.11 seconds

# %%
edsr_model = tf.keras.models.load_model('models/edsr_model_0_5to0_25_deg_dem_4d.keras', custom_objects={
    'psnr': psnr,
    'ssim': ssim,
    'residual_block': residual_block,
    'expand_static_data_dem_0_5': expand_static_data_dem_0_5
}, safe_mode=False)

# %%
test_loss, test_psnr, test_ssim, test_mse, test_mae = edsr_model.evaluate(testX, testY)

print(f"Test Loss: {test_loss}")
print(f"Test PSNR: {test_psnr}")
print(f"Test SSIM: {test_ssim}")
print(f"Test MSE: {test_mse}")
print(f"Test MAE: {test_mae}")
# Out:
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 11s 78ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.2814e-06 - psnr: 50.8288 - ssim: 0.9962
# Test Loss: 0.0013993048341944814
# Test PSNR: 50.83451843261719
# Test SSIM: 0.9962338209152222
# Test MSE: 8.270438229374122e-06
# Test MAE: 0.0013993048341944814

# %%
low_res_input = testX[1]
high_res_data = testY[1]
high_res_output = edsr_model.predict(np.expand_dims(low_res_input, axis=0))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step

# %%
plot_to_compare(low_res_input, np.squeeze(high_res_data),  np.squeeze(high_res_output), 'viridis')

# %%
### Europe
plot_to_compare(low_res_input[40:120, 80:200], np.squeeze(high_res_data)[80:240, 160:400],  np.squeeze(high_res_output)[80:240, 160:400], 'viridis')

# %%
### Greece
plot_to_compare(low_res_input[72:92, 156:180], np.squeeze(high_res_data)[144:184, 312:360],  np.squeeze(high_res_output)[144:184, 312:360], 'viridis')

# %%
# Compute per-pixel metrics
test_mse, test_mae, test_psnr, test_ssim = evaluate_per_pixel(edsr_model, testX, testY)

print("Per-pixel MSE shape:", test_mse.shape)
print("Per-pixel MAE shape:", test_mae.shape)
print("Per-pixel PSNR shape:", test_psnr.shape)
print("Per-pixel SSIM shape:", test_ssim.shape)

mean_mse = np.mean(test_mse)
mean_mae = np.mean(test_mae)
mean_psnr = np.mean(test_psnr)
mean_ssim = np.mean(test_ssim)

print("Mean Per-Pixel MSE:", mean_mse)
print("Mean Per-Pixel MAE:", mean_mae)
print("Mean Per-Pixel PSNR:", mean_psnr)
print("Mean Per-Pixel SSIM:", mean_ssim)
# Out:
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step
# Per-pixel MSE shape: (320, 580, 1)
# Per-pixel MAE shape: (320, 580, 1)
# Per-pixel PSNR shape: (320, 580, 1)
# Per-pixel SSIM shape: (320, 580, 1)
# Mean Per-Pixel MSE: 8.270436e-06
# Mean Per-Pixel MAE: 0.0013993051
# Mean Per-Pixel PSNR: 57.149235
# Mean Per-Pixel SSIM: 0.99912834

# %%
plot_per_pixel_metrics(test_mse, test_mae, test_psnr, test_ssim)

# %%
degrees_mae = denormalize_mae(test_mae, global_Std)
print("Mean Per-Pixel Degrees MAE:", np.mean(degrees_mae))
print("Max Degrees MAE:", degrees_mae.max())
print("Min Degrees MAE:", degrees_mae.min())
plot_degrees_mae(degrees_mae)
# Out:
# Mean Per-Pixel Degrees MAE: 0.089914866
# Max Degrees MAE: 1.034969
# Min Degrees MAE: 0.0065935007

# %%
print("Mean Land-Pixels Degrees MAE:", mean_with_land_mask(degrees_mae, '0_25'))
print("Mean Land-Pixels MAE:", mean_with_land_mask(test_mae, '0_25'))
# Out:
# Mean Land-Pixels Degrees MAE: 0.14241816
# Mean Land-Pixels MAE: 0.00221639
