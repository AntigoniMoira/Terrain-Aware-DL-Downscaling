# %%
# Importing the drive module from google.colab library
from google.colab import drive

# Mounting the Google Drive to the Colab environment
drive.mount('/content/drive')

project_path = '/content/drive/My Drive/DEM_Aware_Downscaling/'

import os
os.chdir(project_path)
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import time
from utils.helpers_functions import read_dataset, z_score_normalize, denormalize_mae, mean_with_land_mask, compute_slope, compute_aspect
from utils.models_functions import psnr, ssim, save_history, save_model, train_model, load_model
from utils.display_functions import plot_history, plot_to_compare, plot_per_pixel_metrics, plot_degrees_mae
from utils.evaluation_functions import evaluate_per_pixel

# %%
dem_path='/content/drive/My Drive/DEM_Aware_Downscaling/dem_data/'
dates_path='/content/drive/My Drive/MSc_Thesis/input_data/index/'
lr_data_path='/content/drive/My Drive/MSc_Thesis/input_data/deg/0_5x0_5/'
hr_data_path='/content/drive/My Drive/MSc_Thesis/input_data/deg/0_25x0_25/'
global_mean = 286.307980744908
global_Std = 64.2568020375484
target_size = (320, 580)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, Add, LeakyReLU, Lambda, Conv2DTranspose, Concatenate
from tensorflow.keras.models import Model

# Load DEMs
dem_data_0_5 = np.load(dem_path + "dem_0_5.npy")
dem_data_0_25 = np.load(dem_path + "dem_0_25.npy")

# Compute aspect
aspect_0_5 = compute_aspect(dem_data_0_5)
aspect_0_25 = compute_aspect(dem_data_0_25)

# Normalize static features
aspect_0_5 = z_score_normalize(aspect_0_5, np.mean(aspect_0_5), np.std(aspect_0_5))
aspect_0_25 = z_score_normalize(aspect_0_25, np.mean(aspect_0_25), np.std(aspect_0_25))

# ---- Convert to Tensors and Expand ----
def to_tensor(x): return tf.expand_dims(tf.constant(x, dtype=tf.float32), axis=-1)

aspect_tensor_0_5 = to_tensor(aspect_0_5)
aspect_tensor_0_25 = to_tensor(aspect_0_25)

def expand_static_aspect_0_5(x):
    batch_size = tf.shape(x)[0]
    return tf.tile(tf.expand_dims(aspect_tensor_0_5, 0), [batch_size, 1, 1, 1])

def expand_static_aspect_0_25(x):
    batch_size = tf.shape(x)[0]
    return tf.tile(tf.expand_dims(aspect_tensor_0_25, 0), [batch_size, 1, 1, 1])

# ---- Residual Block ----
def residual_block(x, filters=32, kernel_size=3, scaling=0.1):
    res = Conv2D(filters, kernel_size, padding='same')(x)
    res = LeakyReLU(alpha=0.2)(res)
    res = Conv2D(filters, kernel_size, padding='same')(res)
    res = Lambda(lambda t: t * scaling)(res)
    return Add()([x, res])

# ---- Model ----
def create_edsr():
    input_img = Input(shape=(160, 290, 1))  # Low-resolution input

    # --- Low-Res Static Features (0.5°) ---
    static_low = Concatenate()([
         Lambda(expand_static_aspect_0_5, output_shape=(160, 290, 1))(input_img)
    ])
    x = Concatenate()([input_img, static_low])

    # Initial Conv Layer
    initial_conv = Conv2D(filters=32, kernel_size=3, padding='same')(x)

    # Residual Blocks
    x = residual_block(initial_conv, filters=32)
    x = residual_block(x, filters=32)
    x = residual_block(x, filters=32)
    x = residual_block(x, filters=32)

    x = Conv2D(filters=32, kernel_size=3, padding='same')(x)
    x = Add()([x, initial_conv])

    # Upsample (learned)
    x = Conv2DTranspose(filters=32, kernel_size=3, strides=2, padding='same')(x)

    # --- High-Res Static Features (0.25°) ---
    static_high = Concatenate()([
        Lambda(expand_static_aspect_0_25, output_shape=(320, 580, 1))(input_img)
    ])
    x = Concatenate()([x, static_high])

    # Fusion Layers
    # x = Conv2D(filters=64, kernel_size=3, padding='same', activation='relu')(x)
    x = Conv2D(filters=32, kernel_size=3, padding='same', activation='relu')(x)
    x = Conv2D(filters=16, kernel_size=3, padding='same', activation='relu')(x)
    # x = Conv2D(filters=8, kernel_size=3, padding='same', activation='relu')(x)

    # Final Conv Layer (Reduces to 1 Output Channel)
    output_img = Conv2D(filters=1, kernel_size=3, padding='same')(x)

    # Model Compilation
    model = Model(inputs=input_img, outputs=output_img)
    model.compile(optimizer='adam', loss='mae', metrics=[psnr, ssim, 'mse', 'mae'])

    return model

# %%
trainX, valX, testX, trainY, valY, testY, trainDates, valDates, testDates = read_dataset(dates_path, lr_data_path, hr_data_path, 'all', 2000, 2020, global_mean, global_Std)

print(trainX.shape)
print(trainY.shape)
print(valX.shape)
print(valY.shape)
print(testX.shape)
print(testY.shape)
# Out:
# (21478, 160, 290, 1)
# (21478, 320, 580, 1)
# (4602, 160, 290, 1)
# (4602, 320, 580, 1)
# (4604, 160, 290, 1)
# (4604, 320, 580, 1)

# %%
# Initialize the model
edsr_model = create_edsr()
edsr_model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 160, 290,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_6 (Lambda)   │ (None, 160, 290,  │          0 │ input_layer_1[0]… │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 160, 290,  │          0 │ lambda_6[0][0]    │
# │ (Concatenate)       │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, 160, 290,  │          0 │ input_layer_1[0]… │
# │ (Concatenate)       │ 2)                │            │ concatenate_4[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 160, 290,  │        608 │ concatenate_5[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 160, 290,  │      9,248 │ conv2d_13[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_4       │ (None, 160, 290,  │          0 │ conv2d_14[0][0]   │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 160, 290,  │      9,248 │ leaky_re_lu_4[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_7 (Lambda)   │ (None, 160, 290,  │          0 │ conv2d_15[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 160, 290,  │          0 │ conv2d_13[0][0],  │
# │                     │ 32)               │            │ lambda_7[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 160, 290,  │      9,248 │ add_5[0][0]       │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_5       │ (None, 160, 290,  │          0 │ conv2d_16[0][0]   │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 160, 290,  │      9,248 │ leaky_re_lu_5[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_8 (Lambda)   │ (None, 160, 290,  │          0 │ conv2d_17[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 160, 290,  │          0 │ add_5[0][0],      │
# │                     │ 32)               │            │ lambda_8[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 160, 290,  │      9,248 │ add_6[0][0]       │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_6       │ (None, 160, 290,  │          0 │ conv2d_18[0][0]   │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 160, 290,  │      9,248 │ leaky_re_lu_6[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_9 (Lambda)   │ (None, 160, 290,  │          0 │ conv2d_19[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 160, 290,  │          0 │ add_6[0][0],      │
# │                     │ 32)               │            │ lambda_9[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 160, 290,  │      9,248 │ add_7[0][0]       │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_7       │ (None, 160, 290,  │          0 │ conv2d_20[0][0]   │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 160, 290,  │      9,248 │ leaky_re_lu_7[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_10 (Lambda)  │ (None, 160, 290,  │          0 │ conv2d_21[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 160, 290,  │          0 │ add_7[0][0],      │
# │                     │ 32)               │            │ lambda_10[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 160, 290,  │      9,248 │ add_8[0][0]       │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 160, 290,  │          0 │ conv2d_22[0][0],  │
# │                     │ 32)               │            │ conv2d_13[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_11 (Lambda)  │ (None, 320, 580,  │          0 │ input_layer_1[0]… │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 320, 580,  │      9,248 │ add_9[0][0]       │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_6       │ (None, 320, 580,  │          0 │ lambda_11[0][0]   │
# │ (Concatenate)       │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_7       │ (None, 320, 580,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 33)               │            │ concatenate_6[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 320, 580,  │      9,536 │ concatenate_7[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 320, 580,  │      4,624 │ conv2d_23[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 320, 580,  │        145 │ conv2d_24[0][0]   │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 107,393 (419.50 KB)
#  Trainable params: 107,393 (419.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
start_time = time.time()
history = train_model(edsr_model, trainX, trainY, valX, valY, 250, 32, True, True, 100, 70)
end_time = time.time()

# Print the time taken
print(f"Training time: {end_time - start_time:.2f} seconds")

save_history(history.history, 'models/history_0_5to0_25_deg_dem_4a.pkl')
plot_history(history.history)

save_model(edsr_model, 'models/edsr_model_0_5to0_25_deg_dem_4a.keras')
# Out:
# Epoch 1/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 94s 131ms/step - loss: 0.0272 - mae: 0.0272 - mse: 0.0037 - psnr: 30.6796 - ssim: 0.7536 - val_loss: 0.0068 - val_mae: 0.0068 - val_mse: 1.3331e-04 - val_psnr: 38.7568 - val_ssim: 0.9673 - learning_rate: 0.0010
# Epoch 2/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0063 - mae: 0.0063 - mse: 1.0206e-04 - psnr: 40.0277 - ssim: 0.9724 - val_loss: 0.0053 - val_mae: 0.0053 - val_mse: 5.9780e-05 - val_psnr: 42.2356 - val_ssim: 0.9795 - learning_rate: 0.0010
# Epoch 3/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0050 - mae: 0.0050 - mse: 5.8330e-05 - psnr: 42.4125 - ssim: 0.9829 - val_loss: 0.0049 - val_mae: 0.0049 - val_mse: 5.1821e-05 - val_psnr: 42.8574 - val_ssim: 0.9873 - learning_rate: 0.0010
# Epoch 4/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0043 - mae: 0.0043 - mse: 4.2766e-05 - psnr: 43.7431 - ssim: 0.9870 - val_loss: 0.0046 - val_mae: 0.0046 - val_mse: 4.1074e-05 - val_psnr: 43.8655 - val_ssim: 0.9861 - learning_rate: 0.0010
# Epoch 5/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0042 - mae: 0.0042 - mse: 4.1119e-05 - psnr: 43.9364 - ssim: 0.9886 - val_loss: 0.0040 - val_mae: 0.0040 - val_mse: 3.5131e-05 - val_psnr: 44.5453 - val_ssim: 0.9888 - learning_rate: 0.0010
# Epoch 6/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0036 - mae: 0.0036 - mse: 3.2794e-05 - psnr: 44.8807 - ssim: 0.9895 - val_loss: 0.0034 - val_mae: 0.0034 - val_mse: 3.1690e-05 - val_psnr: 44.9942 - val_ssim: 0.9903 - learning_rate: 0.0010
# Epoch 7/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0037 - mae: 0.0037 - mse: 3.3443e-05 - psnr: 44.8233 - ssim: 0.9901 - val_loss: 0.0047 - val_mae: 0.0047 - val_mse: 4.5261e-05 - val_psnr: 43.4466 - val_ssim: 0.9906 - learning_rate: 0.0010
# Epoch 8/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0036 - mae: 0.0036 - mse: 3.1706e-05 - psnr: 45.0405 - ssim: 0.9905 - val_loss: 0.0041 - val_mae: 0.0041 - val_mse: 3.6063e-05 - val_psnr: 44.4340 - val_ssim: 0.9907 - learning_rate: 0.0010
# Epoch 9/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0035 - mae: 0.0035 - mse: 3.1006e-05 - psnr: 45.1498 - ssim: 0.9906 - val_loss: 0.0033 - val_mae: 0.0033 - val_mse: 2.8580e-05 - val_psnr: 45.4431 - val_ssim: 0.9913 - learning_rate: 0.0010
# Epoch 10/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.
250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0028 - mae: 0.0028 - mse: 2.0281e-05 - psnr: 46.9818 - ssim: 0.9929 - val_loss: 0.0029 - val_mae: 0.0029 - val_mse: 1.9914e-05 - val_psnr: 47.0113 - val_ssim: 0.9933 - learning_rate: 0.0010
# Epoch 22/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0027 - mae: 0.0027 - mse: 1.8749e-05 - psnr: 47.2937 - ssim: 0.9934 - val_loss: 0.0024 - val_mae: 0.0024 - val_mse: 1.6455e-05 - val_psnr: 47.8405 - val_ssim: 0.9935 - learning_rate: 0.0010
# Epoch 23/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0026 - mae: 0.0026 - mse: 1.8680e-05 - psnr: 47.3312 - ssim: 0.9932 - val_loss: 0.0027 - val_mae: 0.0027 - val_mse: 1.7726e-05 - val_psnr: 47.5169 - val_ssim: 0.9936 - learning_rate: 0.0010
# Epoch 24/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0028 - mae: 0.0028 - mse: 1.9306e-05 - psnr: 47.1950 - ssim: 0.9936 - val_loss: 0.0024 - val_mae: 0.0024 - val_mse: 1.5552e-05 - val_psnr: 48.0863 - val_ssim: 0.9938 - learning_rate: 0.0010
# Epoch 25/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0025 - mae: 0.0025 - mse: 1.6636e-05 - psnr: 47.8161 - ssim: 0.9936 - val_loss: 0.0034 - val_mae: 0.0034 - val_mse: 2.3276e-05 - val_psnr: 46.3354 - val_ssim: 0.9939 - learning_rate: 0.0010
# Epoch 26/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0027 - mae: 0.0027 - mse: 1.9096e-05 - psnr: 47.3784 - ssim: 0.9935 - val_loss: 0.0027 - val_mae: 0.0027 - val_mse: 1.8310e-05 - val_psnr: 47.3777 - val_ssim: 0.9936 - learning_rate: 0.0010
# Epoch 27/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0027 - mae: 0.0027 - mse: 1.8022e-05 - psnr: 47.4773 - ssim: 0.9937 - val_loss: 0.0025 - val_mae: 0.0025 - val_mse: 1.6333e-05 - val_psnr: 47.8724 - val_ssim: 0.9940 - learning_rate: 0.0010
# Epoch 28/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0026 - mae: 0.0026 - mse: 1.7213e-05 - psnr: 47.6666 - ssim: 0.9938 - val_loss: 0.0028 - val_mae: 0.0028 - val_mse: 1.9027e-05 - val_psnr: 47.2134 - val_ssim: 0.9940 - learning_rate: 0.0010
# Epoch 29/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0025 - mae: 0.0025 - mse: 1.6623e-05 - psnr: 47.8106 - ssim: 0.9940 - val_loss: 0.0025 - val_mae: 0.0025 - val_mse: 1.6764e-05 - val_psnr: 47.7632 - val_ssim: 0.9942 - learning_rate: 0.0010
# Epoch 30/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0024 - mae: 0.0024 - mse: 1.5786e-05 - psnr: 48.0331 - ssim: 0.9940 - val_loss: 0.0026 - val_mae: 0.0026 - val_mse: 1.6191e-05 - val_psnr: 47.9124 - val_ssim: 0.9942 - learning_rate: 0.0010
# Epoch 31/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0025 - mae: 0.0025 - mse: 1.6012e-05 - psnr: 47.9838 - ssim: 0.9941 - val_loss: 0.0023 - val_mae: 0.0023 - val_mse: 1.4433e-05 - val_psnr: 48.4111 - val_ssim: 0.9941 - learning_rate: 0.0010
# Epoch 32/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0024 - mae: 0.0024 - mse: 1.5593e-05 - psnr: 48.0856 - ssim: 0.9942 - val_loss: 0.0023 - val_mae: 0.0023 - val_mse: 1.4867e-05 - val_psnr: 48.2837 - val_ssim: 0.9942 - learning_rate: 0.0010
# Epoch 33/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0024 - mae: 0.0024 - mse: 1.5849e-05 - psnr: 48.2800 - ssim: 0.9941 - val_loss: 0.0027 - val_mae: 0.0027 - val_mse: 1.8727e-05 - val_psnr: 47.2797 - val_ssim: 0.9936 - learning_rate: 0.0010
# Epoch 34/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0025 - mae: 0.0025 - mse: 1.6669e-05 - psnr: 47.8035 - ssim: 0.9938 - val_loss: 0.0026 - val_mae: 0.0026 - val_mse: 1.7380e-05 - val_psnr: 47.6058 - val_ssim: 0.9942 - learning_rate: 0.0010
# Epoch 35/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0025 - mae: 0.0025 - mse: 1.6235e-05 - psnr: 47.9168 - ssim: 0.9942 - val_loss: 0.0023 - val_mae: 0.0023 - val_mse: 1.4791e-05 - val_psnr: 48.3050 - val_ssim: 0.9941 - learning_rate: 0.0010
# Epoch 36/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0023 - mae: 0.0023 - mse: 1.4523e-05 - psnr: 48.3954 - ssim: 0.9943 - val_loss: 0.0024 - val_mae: 0.0024 - val_mse: 1.5287e-05 - val_psnr: 48.1628 - val_ssim: 0.9945 - learning_rate: 0.0010
# Epoch 37/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0023 - mae: 0.0023 - mse: 1.4886e-05 - psnr: 48.2920 - ssim: 0.9944 - val_loss: 0.0024 - val_mae: 0.0024 - val_mse: 1.4647e-05 - val_psnr: 48.3481 - val_ssim: 0.9944 - learning_rate: 0.0010
# Epoch 38/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0022 - mae: 0.0022 - mse: 1.3801e-05 - psnr: 48.6107 - ssim: 0.9945 - val_loss: 0.0031 - val_mae: 0.0031 - val_mse: 2.2988e-05 - val_psnr: 46.3956 - val_ssim: 0.9940 - learning_rate: 0.0010
# Epoch 39/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0023 - mae: 0.0023 - mse: 1.4528e-05 - psnr: 48.4187 - ssim: 0.9945 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.2647e-05 - val_psnr: 48.9862 - val_ssim: 0.9946 - learning_rate: 0.0010
# Epoch 40/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0024 - mae: 0.0024 - mse: 1.4955e-05 - psnr: 48.2785 - ssim: 0.9945 - val_loss: 0.0024 - val_mae: 0.0024 - val_mse: 1.4967e-05 - val_psnr: 48.2544 - val_ssim: 0.9944 - learning_rate: 0.0010
# Epoch 41/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0023 - mae: 0.0023 - mse: 1.4356e-05 - psnr: 48.4474 - ssim: 0.9945 - val_loss: 0.0023 - val_mae: 0.0023 - val_mse: 1.4029e-05 - val_psnr: 48.5342 - val_ssim: 0.9943 - learning_rate: 0.0010
# Epoch 42/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0023 - mae: 0.0023 - mse: 1.4063e-05 - psnr: 48.5320 - ssim: 0.9946 - val_loss: 0.0024 - val_mae: 0.0024 - val_mse: 1.4943e-05 - val_psnr: 48.2619 - val_ssim: 0.9948 - learning_rate: 0.0010
# Epoch 43/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0022 - mae: 0.0022 - mse: 1.3588e-05 - psnr: 48.6810 - ssim: 0.9947 - val_loss: 0.0025 - val_mae: 0.0025 - val_mse: 1.6916e-05 - val_psnr: 47.7272 - val_ssim: 0.9948 - learning_rate: 0.0010
# Epoch 44/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 114ms/step - loss: 0.0023 - mae: 0.0023 - mse: 1.4269e-05 - psnr: 48.4982 - ssim: 0.9946 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.2894e-05 - val_psnr: 48.9011 - val_ssim: 0.9948 - learning_rate: 0.0010
# Epoch 45/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0021 - mae: 0.0021 - mse: 1.2863e-05 - psnr: 48.9191 - ssim: 0.9948 - val_loss: 0.0019 - val_mae: 0.0019 - val_mse: 1.1961e-05 - val_psnr: 49.2288 - val_ssim: 0.9949 - learning_rate: 0.0010
# Epoch 46/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0020 - mae: 0.0020 - mse: 1.2507e-05 - psnr: 49.0411 - ssim: 0.9949 - val_loss: 0.0023 - val_mae: 0.0023 - val_mse: 1.4497e-05 - val_psnr: 48.3917 - val_ssim: 0.9943 - learning_rate: 0.0010
# Epoch 47/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0023 - mae: 0.0023 - mse: 1.4845e-05 - psnr: 48.3946 - ssim: 0.9946 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.2156e-05 - val_psnr: 49.1577 - val_ssim: 0.9948 - learning_rate: 0.0010
# Epoch 48/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0021 - mae: 0.0021 - mse: 1.2462e-05 - psnr: 49.0607 - ssim: 0.9950 - val_loss: 0.0022 - val_mae: 0.0022 - val_mse: 1.3129e-05 - val_psnr: 48.8230 - val_ssim: 0.9949 - learning_rate: 0.0010
# Epoch 49/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0022 - mae: 0.0022 - mse: 1.3530e-05 - psnr: 48.7178 - ssim: 0.9949 - val_loss: 0.0023 - val_mae: 0.0023 - val_mse: 1.3507e-05 - val_psnr: 48.7017 - val_ssim: 0.9950 - learning_rate: 0.0010
# Epoch 50/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0022 - mae: 0.0022 - mse: 1.2995e-05 - psnr: 48.8866 - ssim: 0.9950 - val_loss: 0.0021 - val_mae: 0.0021 - val_mse: 1.2283e-05 - val_psnr: 49.1119 - val_ssim: 0.9951 - learning_rate: 0.0010
# Epoch 51/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0021 - mae: 0.0021 - mse: 1.2438e-05 - psnr: 49.0680 - ssim: 0.9950 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.1737e-05 - val_psnr: 49.3107 - val_ssim: 0.9951 - learning_rate: 0.0010
# Epoch 52/250
# 672/672 ━━━━━━━━━━━━━━━━━━━━ 76s 113ms/step - loss: 0.0021 - mae: 0.0021 - mse: 1.2711e-05 - psnr: 49.0029 - ssim: 0.9950 - val_loss: 0.0020 - val_mae: 0.0020 - val_mse: 1.
    'residual_block': residual_block,
    'expand_static_aspect_0_5': expand_static_aspect_0_5,
    'expand_static_aspect_0_25': expand_static_aspect_0_25
}, safe_mode=False)

# %%
test_loss, test_psnr, test_ssim, test_mse, test_mae = edsr_model.evaluate(testX, testY)

print(f"Test Loss: {test_loss}")
print(f"Test PSNR: {test_psnr}")
print(f"Test SSIM: {test_ssim}")
print(f"Test MSE: {test_mse}")
print(f"Test MAE: {test_mae}")
# Out:
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 11s 76ms/step - loss: 0.0014 - mae: 0.0014 - mse: 8.4539e-06 - psnr: 50.7396 - ssim: 0.9962
# Test Loss: 0.0014081110712140799
# Test PSNR: 50.74470901489258
# Test SSIM: 0.9962028861045837
# Test MSE: 8.44349960971158e-06
# Test MAE: 0.001408110954798758

# %%
low_res_input = testX[1]
high_res_data = testY[1]
high_res_output = edsr_model.predict(np.expand_dims(low_res_input, axis=0))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step

# %%
plot_to_compare(low_res_input, np.squeeze(high_res_data),  np.squeeze(high_res_output), 'viridis')

# %%
### Europe
plot_to_compare(low_res_input[40:120, 80:200], np.squeeze(high_res_data)[80:240, 160:400],  np.squeeze(high_res_output)[80:240, 160:400], 'viridis')

# %%
### Greece
plot_to_compare(low_res_input[72:92, 156:180], np.squeeze(high_res_data)[144:184, 312:360],  np.squeeze(high_res_output)[144:184, 312:360], 'viridis')

# %%
# Compute per-pixel metrics
test_mse, test_mae, test_psnr, test_ssim = evaluate_per_pixel(edsr_model, testX, testY)

print("Per-pixel MSE shape:", test_mse.shape)
print("Per-pixel MAE shape:", test_mae.shape)
print("Per-pixel PSNR shape:", test_psnr.shape)
print("Per-pixel SSIM shape:", test_ssim.shape)

mean_mse = np.mean(test_mse)
mean_mae = np.mean(test_mae)
mean_psnr = np.mean(test_psnr)
mean_ssim = np.mean(test_ssim)

print("Mean Per-Pixel MSE:", mean_mse)
print("Mean Per-Pixel MAE:", mean_mae)
print("Mean Per-Pixel PSNR:", mean_psnr)
print("Mean Per-Pixel SSIM:", mean_ssim)
# Out:
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step
# Per-pixel MSE shape: (320, 580, 1)
# Per-pixel MAE shape: (320, 580, 1)
# Per-pixel PSNR shape: (320, 580, 1)
# Per-pixel SSIM shape: (320, 580, 1)
# Mean Per-Pixel MSE: 8.443498e-06
# Mean Per-Pixel MAE: 0.0014081112
# Mean Per-Pixel PSNR: 57.11459
# Mean Per-Pixel SSIM: 0.99910283

# %%
plot_per_pixel_metrics(test_mse, test_mae, test_psnr, test_ssim)

# %%
degrees_mae = denormalize_mae(test_mae, global_Std)
print("Mean Per-Pixel Degrees MAE:", np.mean(degrees_mae))
print("Max Degrees MAE:", degrees_mae.max())
print("Min Degrees MAE:", degrees_mae.min())
plot_degrees_mae(degrees_mae)
# Out:
# Mean Per-Pixel Degrees MAE: 0.090480715
# Max Degrees MAE: 1.042022
# Min Degrees MAE: 0.006433952

# %%
print("Mean Land-Pixels Degrees MAE:", mean_with_land_mask(degrees_mae, '0_25'))
print("Mean Land-Pixels MAE:", mean_with_land_mask(test_mae, '0_25'))
# Out:
# Mean Land-Pixels Degrees MAE: 0.14352325
# Mean Land-Pixels MAE: 0.0022335881
